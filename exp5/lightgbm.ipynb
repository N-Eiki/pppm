# %%
local = True
data_transform = False
# transform_method = "standardscaler"  
transform_method = "rankgauss"

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %% [markdown]
# # About this notebook
# - Deberta-v3-large starter code
# - pip wheels is [here](https://www.kaggle.com/code/yasufuminakama/pppm-pip-wheels)
# - Training notebook is [here](https://www.kaggle.com/code/yasufuminakama/pppm-deberta-v3-large-baseline-w-w-b-train)
#
# If this notebook is helpful, feel free to upvote :)

# %%
# ====================================================
# Directory settings
# ====================================================
exp_names = [
            'albert-base-v2',
             "roberta-base",
            "microsoft-mpnet-base",
            "funnel-transformer-large512",
             "deberta-v3-base",
             "microsoft-deberta-large",
             
            ]

# stacking_exp_name = f"4model_stacking_1dcnn_{transform_method}"
stacking_exp_name = f"6model_stacking_lgbm_xgb"
import os
if local:
    INPUT_DIR = '../../data/us-patent-phrase-to-phrase-matching/'
    
    OUTPUT_DIR = f"./output/{stacking_exp_name}/"
else:
    INPUT_DIR = '../input/us-patent-phrase-to-phrase-matching/'
    OUTPUT_DIR = './'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
def get_logger(filename=OUTPUT_DIR+'train'):
    from logging import getLogger, INFO, StreamHandler, FileHandler, Formatter
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=f"{filename}.log")
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = get_logger()

# %% [markdown]
# # CFG

# %%
# ====================================================
# CFG
# ====================================================
class CFG:
    
    #######実行ごとに変更必要の可能性あり
    EXP_NAMES = exp_names
    models=[
            "roberta-base",
            "microsoft/mpnet-base",
            "funnel-transformer-large512",
            "microsoft/deberta-v3-base",
            "microsoft/deberta-v3-large",
            'albert-base-v2',
            
           ]
    folder_names = [
                    "roberta-base",
                    "mpnetbase",
                    "funnellarge512fold4",
                   "debertabase",
                   "debertalarge",
                    
                    'albert-base-v2',
                  ]
    
    use_hidden_states = [
        False,False,
        False, True, False, False
    ]
    
    max_lens = [
        175,125,
        125, 133, 133,127,]
    pass_folds_flg = False
    pass_folds  = [
        -1,
        -1, -1, -1
    ]
    
    #######
    paths = []
    config_paths = []
    model_paths = []
    for EXP_NAME in EXP_NAMES:
        if local:
            path=f"../exp4/output/{EXP_NAME}/"
            config_path=path+'config.pth'
            model_path=f'../exp4/output/{EXP_NAME}/'
            cpc_path = f"{INPUT_DIR}/cpc_texts.pth"
        else:
            path=f"../input/{folder_name}/{EXP_NAME}/"
            config_path=path+'config.pth'
            model_path=f'../input/{folder_name}/'
            cpc_path = "../input/pppm-deberta-v3-large-baseline-w-w-b-train/cpc_texts.pth"
        paths.append(path)
        config_paths.append(config_path)
        model_paths.append(model_path)
        
    num_workers=4
    hidden_states = []
    for model in models:
        if "small" in model:
            hidden_state  = 512
        elif "base" in model:
            hidden_state  = 768
        elif "large" in model:
            hidden_state  = 1024
        elif "xlarge" in model:
            hidden_state =  1536
        hidden_states.append(hidden_state)
    
    batch_size=32
    fc_dropout=0.2
    target_size=1
    max_len=133
    seed=42
    n_fold=4
    trn_fold=[i for i in range(n_fold)]
    pass_fold = []
#     torch.load(CFG.model_path+f"{CFG.model.replace('/', '-')}_fold{fold}_best.pth",

# %% [markdown]
# # Library

# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import re
import ast
import sys
import copy
import json
import time
import math
import shutil
import string
import pickle
import random
import joblib
import itertools
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

import torch
print(f"torch.__version__: {torch.__version__}")
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
from torch.optim import Adam, SGD, AdamW
from torch.utils.data import DataLoader, Dataset

if not local:
    os.system('pip uninstall -y transformers')
    os.system('pip uninstall -y tokenizers')
    os.system('python -m pip install --no-index --find-links=../input/pppm-pip-wheels-dataset transformers')
    os.system('python -m pip install --no-index --find-links=../input/pppm-pip-wheels-dataset tokenizers')
import tokenizers
import transformers
print(f"tokenizers.__version__: {tokenizers.__version__}")
print(f"transformers.__version__: {transformers.__version__}")
from transformers import AutoTokenizer, AutoModel, AutoConfig
from transformers import get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup
# %env TOKENIZERS_PARALLELISM=true

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device("cpu")

print(device)
# Out:
# torch.__version__: 1.9.0+cu111
# tokenizers.__version__: 0.11.0
# transformers.__version__: 4.16.2
# env: TOKENIZERS_PARALLELISM=true
# cpu

# %%
import numpy as np
import random
import pandas as pd
from copy import deepcopy as dp

from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.modules.loss import _WeightedLoss

# %% [markdown]
# # Utils

# %%
# ====================================================
# Utils
# ====================================================
def get_score(y_true, y_pred):
    score = sp.stats.pearsonr(y_true, y_pred)[0]
    return score




def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed_everything(seed=42)

# %% [markdown]
# # OOF

# %%
# oof_df = pd.read_pickle(CFG.path+'oof_df.pkl')
# labels = oof_df['score'].values
# preds = oof_df['pred'].values
# score = get_score(labels, preds)
# LOGGER.info(f'CV Score: {score:<.4f}')
train = pd.DataFrame()
for path in CFG.paths:
    oof_file = [f for f in os.listdir(path) if "oof_df.pkl" in f][0]
    oof_df = pd.read_pickle(path+oof_file)
    labels = oof_df['score'].values
    preds = oof_df[["id",'pred']]
    score = get_score(labels, preds["pred"])
    LOGGER.info(f'CV Score: {score:<.4f}')
    train = pd.concat([train, oof_df[["pred"]]],axis=1)
train.columns = [c+str(i) for i, c in enumerate(train.columns)]
train["id"] = preds["id"]
# Out:
# CV Score: 0.7817
# CV Score: 0.7990
# CV Score: 0.8159
# CV Score: 0.8485
# CV Score: 0.8422
# CV Score: 0.8574

# %%
_train = pd.read_csv(f"{INPUT_DIR}train.csv")

# %%
# train = 
cols = train.columns.tolist()
train = train.merge(_train, on="id")[cols + ["score"]+["anchor"]]
targets = train["score"]

# %% [markdown]
# # lightgbm

# %%
import lightgbm as lgb
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

dfx = pd.get_dummies(train, columns=["score"]).groupby(["anchor"], as_index=False).sum()
cols = [c for c in dfx.columns if c.startswith("score_") or c == "anchor"]
dfx = dfx[cols]

mskf = MultilabelStratifiedKFold(n_splits=CFG.n_fold, shuffle=True, random_state=42)
labels = [c for c in dfx.columns if c != "anchor"]
dfx_labels = dfx[labels]
dfx["fold"] = -1

for fold, (trn_, val_) in enumerate(mskf.split(dfx, dfx_labels)):
    print(len(trn_), len(val_))
    dfx.loc[val_, "fold"] = fold

train = train.merge(dfx[["anchor", "fold"]], on="anchor", how="left")
print(train.fold.value_counts())

train.head()
# Out:
# 550 183
# 549 184
# 550 183
# 550 183
# 3    9622
# 0    9379
# 1    8860
# 2    8612
# Name: fold, dtype: int64
#       pred0     pred1     pred2     pred3     pred4     pred5                id  score     anchor  fold
# 0  0.403073  0.003255  0.030808  0.000880  0.003149  0.000215  54c1e3b9184cb5b6   0.00  abatement     0
# 1  0.000860  0.259491  0.276099  0.236394  0.247720  0.241680  ef2d4c2e6bbb208d   0.25  abatement     0
# 2  0.267246  0.478204  0.491518  0.428095  0.501632  0.503771  4c3f2750e7540ab7   0.50  abatement     0
# 3  0.476264  0.518456  0.506613  0.482324  0.536995  0.479786  bfd7270f57530991   0.50  abatement     0
# 4  0.458974  0.467527  0.448548  0.273144  0.073328  0.005082  cc96541d4987b399   0.00  abatement     0

# %%
class lgbm_cfg:
    n_splits = CFG.n_fold
    SEED = [1999, 42, 2022]
    params = {
        "lambda_l1":100, #大きいほど正則化が大きい
        'boosting_type': 'gbdt',      # GBDTを指定
        'objective': 'regression',    # 回帰を指定
        'metric': 'rmse',             # 回帰の評価関数
        'learning_rate': 0.01,
    }

# %%
def train_lgbm(train, seed, fold_num, features, params):
    oof = np.zeros((len(train), 1))
    tr_idx = train[train.fold!=fold_num].index
    va_idx = train[train.fold==fold_num].index
    
    train_x = train.iloc[tr_idx][features]
    train_y = train.iloc[tr_idx]["score"]
    
    valid_x = train.iloc[va_idx][features]
    valid_y = train.iloc[va_idx]["score"]
    
    train_set = lgb.Dataset(train_x, train_y)
    val_set = lgb.Dataset(valid_x, valid_y)

    model = lgb.train(params, 
                          train_set, 
                          num_boost_round = 2500,
                          early_stopping_rounds = 50,
                          valid_sets = [train_set, val_set], 
                          verbose_eval = -1)
    pd.to_pickle(model, f"{OUTPUT_DIR}fold{fold_num}_seed{seed}_lgbm.pkl")
    pred = model.predict(valid_x, num_iteration=model.best_iteration).reshape(-1,1)
    score = get_score(valid_y, pred)
    LOGGER.info(f"seed{seed}, fold{fold_num}, score {score}")
    oof[va_idx] = pred
    return oof

# %%
features = train.columns[:len(exp_names)]
features
# Out:
# Index(['pred0', 'pred1', 'pred2', 'pred3', 'pred4', 'pred5'], dtype='object')

# %%
oof_df = np.zeros((len(train), 1))
for seed in lgbm_cfg.SEED:
    lgbm_cfg.params["seed"] = seed
    for fold_num in range(lgbm_cfg.n_splits,):
        _oof = train_lgbm(train,seed, fold_num, features, lgbm_cfg.params)
        oof_df += _oof/len(lgbm_cfg.SEED)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000933 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 27094, number of used features: 6
# [LightGBM] [Info] Start training from score 0.360809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 0.126137	valid_1's rmse: 0.134556
# seed2022, fold3, score [0.8523871819952015]

# %%
score = get_score(targets, oof_df)
LOGGER.info(f"lgbm score {score}")
# Out:
# lgbm score [0.86645155278507]

# %%
train["score"] = oof_df

train.to_csv(f"{OUTPUT_DIR}oof_lgbm_df.csv",index=False)

# %% [markdown]
# # xgboost

# %%
import xgboost as xgb

# %%
class xgb_cfg:
    params = {
        'objective': 'reg:squarederror','silent':1, 'random_state':None, 
        # 学習用の指標 (RMSE)
        'eval_metric': 'rmse',
    }
    SEED = [1999, 42, 2022]
    n_splits = CFG.n_fold

# %%
def train_xgb(train, seed, fold_num, features, params):
    oof = np.zeros((len(train), 1))
    tr_idx = train[train.fold!=fold_num].index
    va_idx = train[train.fold==fold_num].index
    
    train_x = train.iloc[tr_idx][features]
    train_y = train.iloc[tr_idx]["score"]
    
    valid_x = train.iloc[va_idx][features]
    valid_y = train.iloc[va_idx]["score"]
    
    train_set = xgb.DMatrix(train_x, train_y)
    val_set = xgb.DMatrix(valid_x, valid_y)
    
    num_round = 2500
    watchlist = [(train_set, 'train'), (val_set, 'eval')]
    model = xgb.train(params,
                    train_set,#訓練データ
                    num_round,#設定した学習回数
                    early_stopping_rounds=50,
                    evals=watchlist,
                    )
    
    pd.to_pickle(model, f"{OUTPUT_DIR}fold{fold_num}_seed{seed}_xgb.pkl")
    
    val = xgb.DMatrix(valid_x)
    pred = model.predict(val, ntree_limit=model.best_ntree_limit).reshape(-1,1)
    
    score = get_score(valid_y, pred)
    LOGGER.info(f"seed{seed}, fold{fold_num}, score {score}")
    oof[va_idx] = pred
    return oof

# %%
oof_df = np.zeros((len(train), 1))
for seed in xgb_cfg.SEED:
    xgb_cfg.params["seed"] = seed
    for fold_num in range(xgb_cfg.n_splits,):
        _oof = train_xgb(train,seed, fold_num, features, xgb_cfg.params)
        oof_df += _oof/len(xgb_cfg.SEED)
# Out:
# [12:46:02] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-rmse:0.17744	eval-rmse:0.17661
# [1]	train-rmse:0.12484	eval-rmse:0.12442
# [2]	train-rmse:0.08799	eval-rmse:0.08791
# [3]	train-rmse:0.06220	eval-rmse:0.06235
# [4]	train-rmse:0.04413	eval-rmse:0.04457
# [5]	train-rmse:0.03156	eval-rmse:0.03234
# [6]	train-rmse:0.02285	eval-rmse:0.02402
# [7]	train-rmse:0.01692	eval-rmse:0.01851
# [8]	train-rmse:0.01298	eval-rmse:0.01500
# [9]	train-rmse:0.01044	eval-rmse:0.01288
# [10]	train-rmse:0.00886	eval-rmse:0.01163
# [11]	train-rmse:0.00792	eval-rmse:0.01091
# [12]	train-rmse:0.00737	eval-rmse:0.01053
# [13]	train-rmse:0.00702	eval-rmse:0.01028
# [14]	train-rmse:0.00677	eval-rmse:0.01009
# [15]	train-rmse:0.00661	eval-rmse:0.01002
# [16]	train-rmse:0.00651	eval-rmse:0.00996
# [17]	train-rmse:0.00639	eval-rmse:0.00989
# [18]	train-rmse:0.00633	eval-rmse:0.00985
# [19]	train-rmse:0.00626	eval-rmse:0.00983
# [20]	train-rmse:0.00621	eval-rmse:0.00980
# [21]	train-rmse:0.00613	eval-rmse:0.00976
# [22]	train-rmse:0.00610	eval-rmse:0.00975
# [23]	train-rmse:0.00604	eval-rmse:0.00973
# [24]	train-rmse:0.00602	eval-rmse:0.00973
# [25]	train-rmse:0.00596	eval-rmse:0.00971
# [26]	train-rmse:0.00593	eval-rmse:0.00970
# [27]	train-rmse:0.00588	eval-rmse:0.00966
# [28]	train-rmse:0.00583	eval-rmse:0.00963
# [29]	train-rmse:0.00583	eval-rmse:0.00963
# [30]	train-rmse:0.00580	eval-rmse:0.00963
# [31]	train-rmse:0.00577	eval-rmse:0.00963
# [32]	train-rmse:0.00574	eval-rmse:0.00962
# [33]	train-rmse:0.00568	eval-rmse:0.00960
# [34]	train-rmse:0.00566	eval-rmse:0.00959
# [35]	train-rmse:0.00561	eval-rmse:0.00956
# [36]	train-rmse:0.00556	eval-rmse:0.00951
# [37]	train-rmse:0.00552	eval-rmse:0.00950
# [38]	train-rmse:0.00546	eval-rmse:0.00948
# [39]	train-rmse:0.00543	eval-rmse:0.00946
# [40]	train-rmse:0.00541	eval-rmse:0.00946
# [41]	train-rmse:0.00537	eval-rmse:0.00944
# [42]	train-rmse:0.00534	eval-rmse:0.00943
# [43]	train-rmse:0.00534	eval-rmse:0.00942
# [44]	train-rmse:0.00530	eval-rmse:0.00940
# [45]	train-rmse:0.00526	eval-rmse:0.00939
# [46]	train-rmse:0.00524	eval-rmse:0.00938
# [47]	train-rmse:0.00522	eval-rmse:0.00938
# [48]	train-rmse:0.00520	eval-rmse:0.00938
# [49]	train-rmse:0.00517	eval-rmse:0.00938
# [50]	train-rmse:0.00514	eval-rmse:0.00938
# [51]	train-rmse:0.00511	eval-rmse:0.00935
# [52]	train-rmse:0.00509	eval-rmse:0.00935
# [53]	train-rmse:0.00508	eval-rmse:0.00935
# [54]	train-rmse:0.00506	eval-rmse:0.00935
# [55]	train-rmse:0.00504	eval-rmse:0.00934
# [56]	train-rmse:0.00502	eval-rmse:0.00934
# [57]	train-rmse:0.00499	eval-rmse:0.00933
# [58]	train-rmse:0.00497	eval-rmse:0.00932
# [59]	train-rmse:0.00495	eval-rmse:0.00931
# [60]	train-rmse:0.00494	eval-rmse:0.00930
# [61]	train-rmse:0.00492	eval-rmse:0.00930
# [62]	train-rmse:0.00490	eval-rmse:0.00930
# [63]	train-rmse:0.00488	eval-rmse:0.00929
# [64]	train-rmse:0.00486	eval-rmse:0.00929
# [65]	train-rmse:0.00483	eval-rmse:0.00929
# [66]	train-rmse:0.00482	eval-rmse:0.00929
# [67]	train-rmse:0.00480	eval-rmse:0.00929
# [68]	train-rmse:0.00479	eval-rmse:0.00929
# [69]	train-rmse:0.00479	eval-rmse:0.00930
# [70]	train-rmse:0.00478	eval-rmse:0.00930
# [71]	train-rmse:0.00476	eval-rmse:0.00929
# [72]	train-rmse:0.00473	eval-rmse:0.00929
# [73]	train-rmse:0.00471	eval-rmse:0.00928
# [74]	train-rmse:0.00470	eval-rmse:0.00928
# [75]	train-rmse:0.00469	eval-rmse:0.00928
# [76]	train-rmse:0.00467	eval-rmse:0.00928
# [77]	train-rmse:0.00466	eval-rmse:0.00928
# [78]	train-rmse:0.00465	eval-rmse:0.00928
# [79]	train-rmse:0.00464	eval-rmse:0.00928
# [80]	train-rmse:0.00463	eval-rmse:0.00928
# [81]	train-rmse:0.00460	eval-rmse:0.00927
# [82]	train-rmse:0.00458	eval-rmse:0.00928
# [83]	train-rmse:0.00456	eval-rmse:0.00927
# [84]	train-rmse:0.00455	eval-rmse:0.00927
# [85]	train-rmse:0.00454	eval-rmse:0.00927
# [86]	train-rmse:0.00453	eval-rmse:0.00927
# [87]	train-rmse:0.00452	eval-rmse:0.00927
# [88]	train-rmse:0.00451	eval-rmse:0.00927
# [89]	train-rmse:0.00449	eval-rmse:0.00926
# [90]	train-rmse:0.00447	eval-rmse:0.00926
# [91]	train-rmse:0.00447	eval-rmse:0.00926
# [92]	train-rmse:0.00446	eval-rmse:0.00926
# [93]	train-rmse:0.00446	eval-rmse:0.00926
# [94]	train-rmse:0.00444	eval-rmse:0.00926
# [95]	train-rmse:0.00442	eval-rmse:0.00925
# [96]	train-rmse:0.00442	eval-rmse:0.00925
# [97]	train-rmse:0.00441	eval-rmse:0.00925
# [98]	train-rmse:0.00441	eval-rmse:0.00925
# [99]	train-rmse:0.00439	eval-rmse:0.00925
# [100]	train-rmse:0.00438	eval-rmse:0.00925
# [101]	train-rmse:0.00437	eval-rmse:0.00924
# [102]	train-rmse:0.00436	eval-rmse:0.00924
# [103]	train-rmse:0.00435	eval-rmse:0.00924
# [104]	train-rmse:0.00433	eval-rmse:0.00924
# [105]	train-rmse:0.00432	eval-rmse:0.00924
# [106]	train-rmse:0.00431	eval-rmse:0.00924
# [107]	train-rmse:0.00430	eval-rmse:0.00924
# [108]	train-rmse:0.00429	eval-rmse:0.00924
# [109]	train-rmse:0.00428	eval-rmse:0.00924
# [110]	train-rmse:0.00427	eval-rmse:0.00924
# [111]	train-rmse:0.00426	eval-rmse:0.00924
# [112]	train-rmse:0.00425	eval-rmse:0.00924
# [113]	train-rmse:0.00424	eval-rmse:0.00924
# [114]	train-rmse:0.00423	eval-rmse:0.00925
# [115]	train-rmse:0.00423	eval-rmse:0.00925
# [116]	train-rmse:0.00422	eval-rmse:0.00925
# [117]	train-rmse:0.00422	eval-rmse:0.00925
# [118]	train-rmse:0.00421	eval-rmse:0.00925
# [119]	train-rmse:0.00419	eval-rmse:0.00925
# [120]	train-rmse:0.00418	eval-rmse:0.00924
# [121]	train-rmse:0.00416	eval-rmse:0.00924
# [122]	train-rmse:0.00415	eval-rmse:0.00924
# [123]	train-rmse:0.00414	eval-rmse:0.00923
# [124]	train-rmse:0.00412	eval-rmse:0.00923
# [125]	train-rmse:0.00410	eval-rmse:0.00923
# [126]	train-rmse:0.00410	eval-rmse:0.00923
# [127]	train-rmse:0.00408	eval-rmse:0.00923
# [128]	train-rmse:0.00407	eval-rmse:0.00923
# [129]	train-rmse:0.00407	eval-rmse:0.00923
# [130]	train-rmse:0.00406	eval-rmse:0.00923
# [131]	train-rmse:0.00404	eval-rmse:0.00923
# [132]	train-rmse:0.00404	eval-rmse:0.00923
# [133]	train-rmse:0.00403	eval-rmse:0.00923
# [134]	train-rmse:0.00402	eval-rmse:0.00923
# [135]	train-rmse:0.00401	eval-rmse:0.00923
# [136]	train-rmse:0.00401	eval-rmse:0.00923
# [137]	train-rmse:0.00400	eval-rmse:0.00923
# [138]	train-rmse:0.00399	eval-rmse:0.00923
# [139]	train-rmse:0.00398	eval-rmse:0.00923
# [140]	train-rmse:0.00396	eval-rmse:0.00923
# [141]	train-rmse:0.00396	eval-rmse:0.00923
# [142]	train-rmse:0.00395	eval-rmse:0.00923
# [143]	train-rmse:0.00394	eval-rmse:0.00923
# [144]	train-rmse:0.00393	eval-rmse:0.00923
# [145]	train-rmse:0.00391	eval-rmse:0.00923
# [146]	train-rmse:0.00390	eval-rmse:0.00922
# [147]	train-rmse:0.00389	eval-rmse:0.00923
# [148]	train-rmse:0.00389	eval-rmse:0.00923
# [149]	train-rmse:0.00388	eval-rmse:0.00923
# [150]	train-rmse:0.00387	eval-rmse:0.00923
# [151]	train-rmse:0.00385	eval-rmse:0.00922
# [152]	train-rmse:0.00383	eval-rmse:0.00923
# [153]	train-rmse:0.00383	eval-rmse:0.00922
# [154]	train-rmse:0.00382	eval-rmse:0.00922
# [155]	train-rmse:0.00381	eval-rmse:0.00922
# [156]	train-rmse:0.00381	eval-rmse:0.00922
# [157]	train-rmse:0.00380	eval-rmse:0.00922
# [158]	train-rmse:0.00379	eval-rmse:0.00922
# [159]	train-rmse:0.00378	eval-rmse:0.00922
# [160]	train-rmse:0.00378	eval-rmse:0.00922
# [161]	train-rmse:0.00377	eval-rmse:0.00922
# [162]	train-rmse:0.00377	eval-rmse:0.00922
# [163]	train-rmse:0.00375	eval-rmse:0.00922
# [164]	train-rmse:0.00374	eval-rmse:0.00922
# [165]	train-rmse:0.00374	eval-rmse:0.00922
# [166]	train-rmse:0.00374	eval-rmse:0.00922
# [167]	train-rmse:0.00373	eval-rmse:0.00922
# [168]	train-rmse:0.00373	eval-rmse:0.00922
# [169]	train-rmse:0.00372	eval-rmse:0.00922
# [170]	train-rmse:0.00372	eval-rmse:0.00922
# [171]	train-rmse:0.00372	eval-rmse:0.00922
# [172]	train-rmse:0.00371	eval-rmse:0.00922
# [173]	train-rmse:0.00371	eval-rmse:0.00922
# [174]	train-rmse:0.00370	eval-rmse:0.00922
# [175]	train-rmse:0.00369	eval-rmse:0.00922
# [176]	train-rmse:0.00369	eval-rmse:0.00922
# [177]	train-rmse:0.00369	eval-rmse:0.00922
# [178]	train-rmse:0.00368	eval-rmse:0.00921
# [179]	train-rmse:0.00367	eval-rmse:0.00921
# [180]	train-rmse:0.00366	eval-rmse:0.00921
# [181]	train-rmse:0.00365	eval-rmse:0.00920
# [182]	train-rmse:0.00365	eval-rmse:0.00921
# [183]	train-rmse:0.00364	eval-rmse:0.00921
# [184]	train-rmse:0.00364	eval-rmse:0.00920
# [185]	train-rmse:0.00363	eval-rmse:0.00920
# [186]	train-rmse:0.00363	eval-rmse:0.00920
# [187]	train-rmse:0.00362	eval-rmse:0.00920
# [188]	train-rmse:0.00361	eval-rmse:0.00920
# [189]	train-rmse:0.00359	eval-rmse:0.00920
# [190]	train-rmse:0.00359	eval-rmse:0.00920
# [191]	train-rmse:0.00357	eval-rmse:0.00919
# [192]	train-rmse:0.00357	eval-rmse:0.00919
# [193]	train-rmse:0.00356	eval-rmse:0.00919
# [194]	train-rmse:0.00355	eval-rmse:0.00919
# [195]	train-rmse:0.00354	eval-rmse:0.00919
# [196]	train-rmse:0.00353	eval-rmse:0.00919
# [197]	train-rmse:0.00352	eval-rmse:0.00919
# [198]	train-rmse:0.00352	eval-rmse:0.00919
# [199]	train-rmse:0.00351	eval-rmse:0.00919
# [200]	train-rmse:0.00350	eval-rmse:0.00919
# [201]	train-rmse:0.00349	eval-rmse:0.00918
# [202]	train-rmse:0.00348	eval-rmse:0.00918
# [203]	train-rmse:0.00348	eval-rmse:0.00918
# [204]	train-rmse:0.00347	eval-rmse:0.00918
# [205]	train-rmse:0.00346	eval-rmse:0.00918
# [206]	train-rmse:0.00345	eval-rmse:0.00918
# [207]	train-rmse:0.00345	eval-rmse:0.00919
# [208]	train-rmse:0.00344	eval-rmse:0.00919
# [209]	train-rmse:0.00344	eval-rmse:0.00919
# [210]	train-rmse:0.00343	eval-rmse:0.00919
# [211]	train-rmse:0.00342	eval-rmse:0.00919
# [212]	train-rmse:0.00341	eval-rmse:0.00919
# [213]	train-rmse:0.00340	eval-rmse:0.00919
# [214]	train-rmse:0.00340	eval-rmse:0.00919
# [215]	train-rmse:0.00340	eval-rmse:0.00919
# [216]	train-rmse:0.00339	eval-rmse:0.00919
# [217]	train-rmse:0.00338	eval-rmse:0.00919
# [218]	train-rmse:0.00338	eval-rmse:0.00919
# [219]	train-rmse:0.00337	eval-rmse:0.00919
# [220]	train-rmse:0.00337	eval-rmse:0.00919
# [221]	train-rmse:0.00336	eval-rmse:0.00919
# [222]	train-rmse:0.00336	eval-rmse:0.00919
# [223]	train-rmse:0.00336	eval-rmse:0.00919
# [224]	train-rmse:0.00335	eval-rmse:0.00919
# [225]	train-rmse:0.00334	eval-rmse:0.00918
# [226]	train-rmse:0.00334	eval-rmse:0.00918
# [227]	train-rmse:0.00333	eval-rmse:0.00918
# [228]	train-rmse:0.00333	eval-rmse:0.00918
# [229]	train-rmse:0.00332	eval-rmse:0.00918
# [230]	train-rmse:0.00332	eval-rmse:0.00918
# [231]	train-rmse:0.00331	eval-rmse:0.00918
# [232]	train-rmse:0.00330	eval-rmse:0.00917
# [233]	train-rmse:0.00329	eval-rmse:0.00917
# [234]	train-rmse:0.00328	eval-rmse:0.00917
# [235]	train-rmse:0.00328	eval-rmse:0.00917
# [236]	train-rmse:0.00327	eval-rmse:0.00917
# [237]	train-rmse:0.00327	eval-rmse:0.00917
# [238]	train-rmse:0.00326	eval-rmse:0.00917
# [239]	train-rmse:0.00326	eval-rmse:0.00917
# [240]	train-rmse:0.00325	eval-rmse:0.00917
# [241]	train-rmse:0.00324	eval-rmse:0.00917
# [242]	train-rmse:0.00324	eval-rmse:0.00917
# [243]	train-rmse:0.00323	eval-rmse:0.00917
# [244]	train-rmse:0.00323	eval-rmse:0.00917
# [245]	train-rmse:0.00323	eval-rmse:0.00917
# [246]	train-rmse:0.00322	eval-rmse:0.00917
# [247]	train-rmse:0.00322	eval-rmse:0.00918
# [248]	train-rmse:0.00322	eval-rmse:0.00917
# [249]	train-rmse:0.00321	eval-rmse:0.00918
# [250]	train-rmse:0.00321	eval-rmse:0.00918
# [251]	train-rmse:0.00320	eval-rmse:0.00918
# [252]	train-rmse:0.00320	eval-rmse:0.00918
# [253]	train-rmse:0.00320	eval-rmse:0.00918
# [254]	train-rmse:0.00318	eval-rmse:0.00917
# [255]	train-rmse:0.00318	eval-rmse:0.00917
# [256]	train-rmse:0.00317	eval-rmse:0.00917
# [257]	train-rmse:0.00316	eval-rmse:0.00917
# [258]	train-rmse:0.00316	eval-rmse:0.00917
# [259]	train-rmse:0.00315	eval-rmse:0.00917
# [260]	train-rmse:0.00315	eval-rmse:0.00917
# [261]	train-rmse:0.00314	eval-rmse:0.00917
# [262]	train-rmse:0.00313	eval-rmse:0.00917
# [263]	train-rmse:0.00313	eval-rmse:0.00917
# [264]	train-rmse:0.00313	eval-rmse:0.00917
# [265]	train-rmse:0.00312	eval-rmse:0.00917
# [266]	train-rmse:0.00311	eval-rmse:0.00917
# [267]	train-rmse:0.00311	eval-rmse:0.00917
# [268]	train-rmse:0.00311	eval-rmse:0.00917
# [269]	train-rmse:0.00310	eval-rmse:0.00918
# [270]	train-rmse:0.00309	eval-rmse:0.00917
# [271]	train-rmse:0.00309	eval-rmse:0.00917
# [272]	train-rmse:0.00309	eval-rmse:0.00917
# [273]	train-rmse:0.00308	eval-rmse:0.00918
# [274]	train-rmse:0.00308	eval-rmse:0.00918
# [275]	train-rmse:0.00307	eval-rmse:0.00918
# [276]	train-rmse:0.00306	eval-rmse:0.00917
# [277]	train-rmse:0.00306	eval-rmse:0.00917
# [278]	train-rmse:0.00305	eval-rmse:0.00917
# [279]	train-rmse:0.00305	eval-rmse:0.00917
# [280]	train-rmse:0.00304	eval-rmse:0.00917
# [281]	train-rmse:0.00304	eval-rmse:0.00917
# [282]	train-rmse:0.00304	eval-rmse:0.00917
# [283]	train-rmse:0.00303	eval-rmse:0.00917
# [284]	train-rmse:0.00303	eval-rmse:0.00917
# [285]	train-rmse:0.00302	eval-rmse:0.00917
# [286]	train-rmse:0.00302	eval-rmse:0.00917
# [287]	train-rmse:0.00301	eval-rmse:0.00917
# [288]	train-rmse:0.00301	eval-rmse:0.00917
# [289]	train-rmse:0.00301	eval-rmse:0.00917
# [290]	train-rmse:0.00300	eval-rmse:0.00917
# seed1999, fold0, score [0.9990658409395438]
# [12:49:38] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-rmse:0.17754	eval-rmse:0.17623
# [1]	train-rmse:0.12494	eval-rmse:0.12416
# [2]	train-rmse:0.08806	eval-rmse:0.08766
# [3]	train-rmse:0.06229	eval-rmse:0.06228
# [4]	train-rmse:0.04423	eval-rmse:0.04450
# [5]	train-rmse:0.03167	eval-rmse:0.03220
# [6]	train-rmse:0.02297	eval-rmse:0.02379
# [7]	train-rmse:0.01706	eval-rmse:0.01817
# [8]	train-rmse:0.01316	eval-rmse:0.01457
# [9]	train-rmse:0.01063	eval-rmse:0.01232
# [10]	train-rmse:0.00910	eval-rmse:0.01103
# [11]	train-rmse:0.00816	eval-rmse:0.01024
# [12]	train-rmse:0.00761	eval-rmse:0.00980
# [13]	train-rmse:0.00730	eval-rmse:0.00955
# [14]	train-rmse:0.00709	eval-rmse:0.00939
# [15]	train-rmse:0.00693	eval-rmse:0.00926
# [16]	train-rmse:0.00678	eval-rmse:0.00917
# [17]	train-rmse:0.00667	eval-rmse:0.00907
# [18]	train-rmse:0.00661	eval-rmse:0.00904
# [19]	train-rmse:0.00653	eval-rmse:0.00899
# [20]	train-rmse:0.00647	eval-rmse:0.00893
# [21]	train-rmse:0.00641	eval-rmse:0.00890
# [22]	train-rmse:0.00635	eval-rmse:0.00887
# [23]	train-rmse:0.00632	eval-rmse:0.00887
# [24]	train-rmse:0.00628	eval-rmse:0.00885
# [25]	train-rmse:0.00625	eval-rmse:0.00886
# [26]	train-rmse:0.00624	eval-rmse:0.00886
# [27]	train-rmse:0.00622	eval-rmse:0.00885
# [28]	train-rmse:0.00619	eval-rmse:0.00885
# [29]	train-rmse:0.00616	eval-rmse:0.00882
# [30]	train-rmse:0.00609	eval-rmse:0.00878
# [31]	train-rmse:0.00606	eval-rmse:0.00877
# [32]	train-rmse:0.00605	eval-rmse:0.00877
# [33]	train-rmse:0.00601	eval-rmse:0.00876
# [34]	train-rmse:0.00600	eval-rmse:0.00876
# [35]	train-rmse:0.00596	eval-rmse:0.00874
# [36]	train-rmse:0.00591	eval-rmse:0.00872
# [37]	train-rmse:0.00589	eval-rmse:0.00872
# [38]	train-rmse:0.00588	eval-rmse:0.00872
# [39]	train-rmse:0.00582	eval-rmse:0.00868
# [40]	train-rmse:0.00582	eval-rmse:0.00868
# [41]	train-rmse:0.00579	eval-rmse:0.00868
# [42]	train-rmse:0.00575	eval-rmse:0.00867
# [43]	train-rmse:0.00571	eval-rmse:0.00865
# [44]	train-rmse:0.00568	eval-rmse:0.00864
# [45]	train-rmse:0.00565	eval-rmse:0.00863
# [46]	train-rmse:0.00561	eval-rmse:0.00863
# [47]	train-rmse:0.00558	eval-rmse:0.00863
# [48]	train-rmse:0.00556	eval-rmse:0.00863
# [49]	train-rmse:0.00552	eval-rmse:0.00861
# [50]	train-rmse:0.00549	eval-rmse:0.00861
# [51]	train-rmse:0.00547	eval-rmse:0.00861
# [52]	train-rmse:0.00544	eval-rmse:0.00859
# [53]	train-rmse:0.00541	eval-rmse:0.00858
# [54]	train-rmse:0.00540	eval-rmse:0.00857
# [55]	train-rmse:0.00540	eval-rmse:0.00857
# [56]	train-rmse:0.00539	eval-rmse:0.00857
# [57]	train-rmse:0.00536	eval-rmse:0.00855
# [58]	train-rmse:0.00532	eval-rmse:0.00854
# [59]	train-rmse:0.00529	eval-rmse:0.00852
# [60]	train-rmse:0.00527	eval-rmse:0.00852
# [61]	train-rmse:0.00526	eval-rmse:0.00852
# [62]	train-rmse:0.00525	eval-rmse:0.00852
# [63]	train-rmse:0.00525	eval-rmse:0.00852
# [64]	train-rmse:0.00525	eval-rmse:0.00852
# [65]	train-rmse:0.00522	eval-rmse:0.00851
# [66]	train-rmse:0.00520	eval-rmse:0.00852
# [67]	train-rmse:0.00519	eval-rmse:0.00851
# [68]	train-rmse:0.00517	eval-rmse:0.00851
# [69]	train-rmse:0.00516	eval-rmse:0.00851
# [70]	train-rmse:0.00514	eval-rmse:0.00851
# [71]	train-rmse:0.00512	eval-rmse:0.00850
# [72]	train-rmse:0.00511	eval-rmse:0.00849
# [73]	train-rmse:0.00508	eval-rmse:0.00849
# [74]	train-rmse:0.00506	eval-rmse:0.00848
# [75]	train-rmse:0.00504	eval-rmse:0.00848
# [76]	train-rmse:0.00500	eval-rmse:0.00847
# [77]	train-rmse:0.00498	eval-rmse:0.00847
# [78]	train-rmse:0.00497	eval-rmse:0.00847
# [79]	train-rmse:0.00495	eval-rmse:0.00846
# [80]	train-rmse:0.00494	eval-rmse:0.00845
# [81]	train-rmse:0.00493	eval-rmse:0.00846
# [82]	train-rmse:0.00491	eval-rmse:0.00844
# [83]	train-rmse:0.00489	eval-rmse:0.00844
# [84]	train-rmse:0.00489	eval-rmse:0.00844
# [85]	train-rmse:0.00488	eval-rmse:0.00843
# [86]	train-rmse:0.00487	eval-rmse:0.00844
# [87]	train-rmse:0.00485	eval-rmse:0.00843
# [88]	train-rmse:0.00483	eval-rmse:0.00843
# [89]	train-rmse:0.00481	eval-rmse:0.00843
# [90]	train-rmse:0.00480	eval-rmse:0.00843
# [91]	train-rmse:0.00478	eval-rmse:0.00844
# [92]	train-rmse:0.00478	eval-rmse:0.00844
# [93]	train-rmse:0.00477	eval-rmse:0.00842
# [94]	train-rmse:0.00475	eval-rmse:0.00842
# [95]	train-rmse:0.00475	eval-rmse:0.00842
# [96]	train-rmse:0.00474	eval-rmse:0.00842
# [97]	train-rmse:0.00473	eval-rmse:0.00843
# [98]	train-rmse:0.00471	eval-rmse:0.00843
# [99]	train-rmse:0.00471	eval-rmse:0.00842
# [100]	train-rmse:0.00471	eval-rmse:0.00842
# [101]	train-rmse:0.00470	eval-rmse:0.00842
# [102]	train-rmse:0.00469	eval-rmse:0.00842
# [103]	train-rmse:0.00467	eval-rmse:0.00842
# [104]	train-rmse:0.00466	eval-rmse:0.00841
# [105]	train-rmse:0.00465	eval-rmse:0.00842
# [106]	train-rmse:0.00464	eval-rmse:0.00841
# [107]	train-rmse:0.00462	eval-rmse:0.00840
# [108]	train-rmse:0.00461	eval-rmse:0.00840
# [109]	train-rmse:0.00458	eval-rmse:0.00840
# [110]	train-rmse:0.00457	eval-rmse:0.00840
# [111]	train-rmse:0.00456	eval-rmse:0.00840
# [112]	train-rmse:0.00456	eval-rmse:0.00840
# [113]	train-rmse:0.00455	eval-rmse:0.00840
# [114]	train-rmse:0.00454	eval-rmse:0.00840
# [115]	train-rmse:0.00453	eval-rmse:0.00840
# [116]	train-rmse:0.00452	eval-rmse:0.00839
# [117]	train-rmse:0.00452	eval-rmse:0.00839
# [118]	train-rmse:0.00451	eval-rmse:0.00840
# [119]	train-rmse:0.00451	eval-rmse:0.00840
# [120]	train-rmse:0.00450	eval-rmse:0.00840
# [121]	train-rmse:0.00449	eval-rmse:0.00840
# [122]	train-rmse:0.00447	eval-rmse:0.00840
# [123]	train-rmse:0.00445	eval-rmse:0.00839
# [124]	train-rmse:0.00444	eval-rmse:0.00839
# [125]	train-rmse:0.00443	eval-rmse:0.00839
# [126]	train-rmse:0.00442	eval-rmse:0.00839
# [127]	train-rmse:0.00441	eval-rmse:0.00839
# [128]	train-rmse:0.00439	eval-rmse:0.00839
# [129]	train-rmse:0.00438	eval-rmse:0.00838
# [130]	train-rmse:0.00438	eval-rmse:0.00838
# [131]	train-rmse:0.00437	eval-rmse:0.00838
# [132]	train-rmse:0.00436	eval-rmse:0.00838
# [133]	train-rmse:0.00436	eval-rmse:0.00838
# [134]	train-rmse:0.00434	eval-rmse:0.00838
# [135]	train-rmse:0.00433	eval-rmse:0.00838
# [136]	train-rmse:0.00432	eval-rmse:0.00839
# [137]	train-rmse:0.00432	eval-rmse:0.00839
# [138]	train-rmse:0.00431	eval-rmse:0.00839
# [139]	train-rmse:0.00430	eval-rmse:0.00839
# [140]	train-rmse:0.00429	eval-rmse:0.00838
# [141]	train-rmse:0.00428	eval-rmse:0.00838
# [142]	train-rmse:0.00428	eval-rmse:0.00838
# [143]	train-rmse:0.00427	eval-rmse:0.00838
# [144]	train-rmse:0.00426	eval-rmse:0.00838
# [145]	train-rmse:0.00425	eval-rmse:0.00838
# [146]	train-rmse:0.00424	eval-rmse:0.00838
# [147]	train-rmse:0.00423	eval-rmse:0.00838
# [148]	train-rmse:0.00422	eval-rmse:0.00838
# [149]	train-rmse:0.00421	eval-rmse:0.00838
# [150]	train-rmse:0.00420	eval-rmse:0.00838
# [151]	train-rmse:0.00418	eval-rmse:0.00838
# [152]	train-rmse:0.00416	eval-rmse:0.00837
# [153]	train-rmse:0.00414	eval-rmse:0.00837
# [154]	train-rmse:0.00414	eval-rmse:0.00837
# [155]	train-rmse:0.00413	eval-rmse:0.00837
# [156]	train-rmse:0.00413	eval-rmse:0.00837
# [157]	train-rmse:0.00412	eval-rmse:0.00837
# [158]	train-rmse:0.00411	eval-rmse:0.00837
# [159]	train-rmse:0.00411	eval-rmse:0.00838
# [160]	train-rmse:0.00411	eval-rmse:0.00838
# [161]	train-rmse:0.00410	eval-rmse:0.00837
# [162]	train-rmse:0.00409	eval-rmse:0.00838
# [163]	train-rmse:0.00408	eval-rmse:0.00838
# [164]	train-rmse:0.00407	eval-rmse:0.00838
# [165]	train-rmse:0.00406	eval-rmse:0.00838
# [166]	train-rmse:0.00405	eval-rmse:0.00838
# [167]	train-rmse:0.00404	eval-rmse:0.00838
# [168]	train-rmse:0.00403	eval-rmse:0.00838
# [169]	train-rmse:0.00402	eval-rmse:0.00838
# [170]	train-rmse:0.00401	eval-rmse:0.00838
# [171]	train-rmse:0.00401	eval-rmse:0.00838
# [172]	train-rmse:0.00400	eval-rmse:0.00838
# [173]	train-rmse:0.00399	eval-rmse:0.00838
# [174]	train-rmse:0.00398	eval-rmse:0.00838
# [175]	train-rmse:0.00398	eval-rmse:0.00838
# [176]	train-rmse:0.00398	eval-rmse:0.00838
# [177]	train-rmse:0.00398	eval-rmse:0.00838
# [178]	train-rmse:0.00397	eval-rmse:0.00838
# [179]	train-rmse:0.00396	eval-rmse:0.00837
# [180]	train-rmse:0.00395	eval-rmse:0.00837
# [181]	train-rmse:0.00394	eval-rmse:0.00837
# [182]	train-rmse:0.00394	eval-rmse:0.00837
# [183]	train-rmse:0.00394	eval-rmse:0.00837
# [184]	train-rmse:0.00394	eval-rmse:0.00838
# [185]	train-rmse:0.00392	eval-rmse:0.00837
# [186]	train-rmse:0.00391	eval-rmse:0.00837
# [187]	train-rmse:0.00390	eval-rmse:0.00837
# [188]	train-rmse:0.00389	eval-rmse:0.00837
# [189]	train-rmse:0.00388	eval-rmse:0.00837
# [190]	train-rmse:0.00387	eval-rmse:0.00837
# [191]	train-rmse:0.00386	eval-rmse:0.00837
# [192]	train-rmse:0.00386	eval-rmse:0.00837
# [193]	train-rmse:0.00385	eval-rmse:0.00837
# [194]	train-rmse:0.00384	eval-rmse:0.00837
# [195]	train-rmse:0.00384	eval-rmse:0.00837
# [196]	train-rmse:0.00383	eval-rmse:0.00837
# [197]	train-rmse:0.00383	eval-rmse:0.00837
# [198]	train-rmse:0.00382	eval-rmse:0.00837
# [199]	train-rmse:0.00382	eval-rmse:0.00837
# [200]	train-rmse:0.00382	eval-rmse:0.00837
# [201]	train-rmse:0.00381	eval-rmse:0.00837
# [202]	train-rmse:0.00380	eval-rmse:0.00837
# [203]	train-rmse:0.00379	eval-rmse:0.00836
# [204]	train-rmse:0.00378	eval-rmse:0.00836
# [205]	train-rmse:0.00378	eval-rmse:0.00836
# [206]	train-rmse:0.00377	eval-rmse:0.00837
# [207]	train-rmse:0.00377	eval-rmse:0.00837
# [208]	train-rmse:0.00376	eval-rmse:0.00837
# [209]	train-rmse:0.00375	eval-rmse:0.00836
# [210]	train-rmse:0.00374	eval-rmse:0.00837
# [211]	train-rmse:0.00374	eval-rmse:0.00837
# [212]	train-rmse:0.00373	eval-rmse:0.00837
# [213]	train-rmse:0.00373	eval-rmse:0.00837
# [214]	train-rmse:0.00372	eval-rmse:0.00837
# [215]	train-rmse:0.00371	eval-rmse:0.00836
# [216]	train-rmse:0.00370	eval-rmse:0.00836
# [217]	train-rmse:0.00369	eval-rmse:0.00836
# [218]	train-rmse:0.00369	eval-rmse:0.00836
# [219]	train-rmse:0.00368	eval-rmse:0.00836
# [220]	train-rmse:0.00367	eval-rmse:0.00836
# [221]	train-rmse:0.00366	eval-rmse:0.00836
# [222]	train-rmse:0.00365	eval-rmse:0.00835
# [223]	train-rmse:0.00365	eval-rmse:0.00835
# [224]	train-rmse:0.00364	eval-rmse:0.00834
# [225]	train-rmse:0.00363	eval-rmse:0.00834
# [226]	train-rmse:0.00362	eval-rmse:0.00834
# [227]	train-rmse:0.00362	eval-rmse:0.00834
# [228]	train-rmse:0.00361	eval-rmse:0.00834
# [229]	train-rmse:0.00361	eval-rmse:0.00834
# [230]	train-rmse:0.00360	eval-rmse:0.00834
# [231]	train-rmse:0.00359	eval-rmse:0.00834
# [232]	train-rmse:0.00358	eval-rmse:0.00834
# [233]	train-rmse:0.00358	eval-rmse:0.00834
# [234]	train-rmse:0.00357	eval-rmse:0.00834
# [235]	train-rmse:0.00356	eval-rmse:0.00834
# [236]	train-rmse:0.00355	eval-rmse:0.00834
# [237]	train-rmse:0.00355	eval-rmse:0.00834
# [238]	train-rmse:0.00354	eval-rmse:0.00834
# [239]	train-rmse:0.00354	eval-rmse:0.00834
# [240]	train-rmse:0.00353	eval-rmse:0.00834
# [241]	train-rmse:0.00352	eval-rmse:0.00834
# [242]	train-rmse:0.00352	eval-rmse:0.00834
# [243]	train-rmse:0.00351	eval-rmse:0.00834
# [244]	train-rmse:0.00350	eval-rmse:0.00834
# [245]	train-rmse:0.00350	eval-rmse:0.00834
# [246]	train-rmse:0.00349	eval-rmse:0.00834
# [247]	train-rmse:0.00349	eval-rmse:0.00834
# [248]	train-rmse:0.00349	eval-rmse:0.00834
# [249]	train-rmse:0.00348	eval-rmse:0.00834
# [250]	train-rmse:0.00348	eval-rmse:0.00834
# [251]	train-rmse:0.00348	eval-rmse:0.00834
# [252]	train-rmse:0.00347	eval-rmse:0.00834
# [253]	train-rmse:0.00347	eval-rmse:0.00834
# [254]	train-rmse:0.00347	eval-rmse:0.00834
# [255]	train-rmse:0.00346	eval-rmse:0.00834
# [256]	train-rmse:0.00346	eval-rmse:0.00834
# [257]	train-rmse:0.00345	eval-rmse:0.00834
# [258]	train-rmse:0.00345	eval-rmse:0.00834
# [259]	train-rmse:0.00344	eval-rmse:0.00834
# [260]	train-rmse:0.00344	eval-rmse:0.00834
# [261]	train-rmse:0.00343	eval-rmse:0.00834
# [262]	train-rmse:0.00343	eval-rmse:0.00834
# [263]	train-rmse:0.00342	eval-rmse:0.00834
# [264]	train-rmse:0.00341	eval-rmse:0.00834
# [265]	train-rmse:0.00340	eval-rmse:0.00834
# [266]	train-rmse:0.00340	eval-rmse:0.00834
# [267]	train-rmse:0.00339	eval-rmse:0.00834
# [268]	train-rmse:0.00339	eval-rmse:0.00834
# [269]	train-rmse:0.00338	eval-rmse:0.00834
# [270]	train-rmse:0.00338	eval-rmse:0.00835
# [271]	train-rmse:0.00337	eval-rmse:0.00835
# [272]	train-rmse:0.00337	eval-rmse:0.00835
# [273]	train-rmse:0.00336	eval-rmse:0.00835
# [274]	train-rmse:0.00335	eval-rmse:0.00835
# [275]	train-rmse:0.00335	eval-rmse:0.00835
# [276]	train-rmse:0.00335	eval-rmse:0.00835
# [277]	train-rmse:0.00334	eval-rmse:0.00835
# [278]	train-rmse:0.00334	eval-rmse:0.00835
# [279]	train-rmse:0.00334	eval-rmse:0.00835
# [280]	train-rmse:0.00333	eval-rmse:0.00836
# [281]	train-rmse:0.00332	eval-rmse:0.00836
# [282]	train-rmse:0.00332	eval-rmse:0.00835
# [283]	train-rmse:0.00331	eval-rmse:0.00835
# [284]	train-rmse:0.00330	eval-rmse:0.00835
# seed1999, fold1, score [0.9992181620756431]
# [12:52:56] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-rmse:0.17668	eval-rmse:0.17855
# [1]	train-rmse:0.12432	eval-rmse:0.12550
# [2]	train-rmse:0.08763	eval-rmse:0.08829
# [3]	train-rmse:0.06194	eval-rmse:0.06237
# [4]	train-rmse:0.04397	eval-rmse:0.04428
# [5]	train-rmse:0.03146	eval-rmse:0.03175
# [6]	train-rmse:0.02281	eval-rmse:0.02323
# [7]	train-rmse:0.01693	eval-rmse:0.01757
# [8]	train-rmse:0.01300	eval-rmse:0.01400
# [9]	train-rmse:0.01049	eval-rmse:0.01182
# [10]	train-rmse:0.00893	eval-rmse:0.01058
# [11]	train-rmse:0.00801	eval-rmse:0.00994
# [12]	train-rmse:0.00747	eval-rmse:0.00958
# [13]	train-rmse:0.00714	eval-rmse:0.00941
# [14]	train-rmse:0.00695	eval-rmse:0.00933
# [15]	train-rmse:0.00682	eval-rmse:0.00929
# [16]	train-rmse:0.00668	eval-rmse:0.00924
# [17]	train-rmse:0.00660	eval-rmse:0.00920
# [18]	train-rmse:0.00650	eval-rmse:0.00915
# [19]	train-rmse:0.00641	eval-rmse:0.00909
# [20]	train-rmse:0.00634	eval-rmse:0.00905
# [21]	train-rmse:0.00630	eval-rmse:0.00905
# [22]	train-rmse:0.00625	eval-rmse:0.00904
# [23]	train-rmse:0.00623	eval-rmse:0.00903
# [24]	train-rmse:0.00619	eval-rmse:0.00901
# [25]	train-rmse:0.00614	eval-rmse:0.00899
# [26]	train-rmse:0.00609	eval-rmse:0.00897
# [27]	train-rmse:0.00608	eval-rmse:0.00897
# [28]	train-rmse:0.00603	eval-rmse:0.00894
# [29]	train-rmse:0.00602	eval-rmse:0.00894
# [30]	train-rmse:0.00596	eval-rmse:0.00890
# [31]	train-rmse:0.00595	eval-rmse:0.00890
# [32]	train-rmse:0.00592	eval-rmse:0.00889
# [33]	train-rmse:0.00591	eval-rmse:0.00888
# [34]	train-rmse:0.00589	eval-rmse:0.00888
# [35]	train-rmse:0.00584	eval-rmse:0.00885
# [36]	train-rmse:0.00580	eval-rmse:0.00885
# [37]	train-rmse:0.00577	eval-rmse:0.00885
# [38]	train-rmse:0.00576	eval-rmse:0.00885
# [39]	train-rmse:0.00572	eval-rmse:0.00883
# [40]	train-rmse:0.00571	eval-rmse:0.00882
# [41]	train-rmse:0.00567	eval-rmse:0.00882
# [42]	train-rmse:0.00566	eval-rmse:0.00881
# [43]	train-rmse:0.00562	eval-rmse:0.00879
# [44]	train-rmse:0.00560	eval-rmse:0.00879
# [45]	train-rmse:0.00558	eval-rmse:0.00879
# [46]	train-rmse:0.00555	eval-rmse:0.00877
# [47]	train-rmse:0.00551	eval-rmse:0.00876
# [48]	train-rmse:0.00548	eval-rmse:0.00876
# [49]	train-rmse:0.00545	eval-rmse:0.00874
# [50]	train-rmse:0.00543	eval-rmse:0.00874
# [51]	train-rmse:0.00543	eval-rmse:0.00874
# [52]	train-rmse:0.00540	eval-rmse:0.00873
# [53]	train-rmse:0.00537	eval-rmse:0.00872
# [54]	train-rmse:0.00534	eval-rmse:0.00870
# [55]	train-rmse:0.00531	eval-rmse:0.00869
# [56]	train-rmse:0.00529	eval-rmse:0.00869
# [57]	train-rmse:0.00526	eval-rmse:0.00868
# [58]	train-rmse:0.00522	eval-rmse:0.00867
# [59]	train-rmse:0.00520	eval-rmse:0.00866
# [60]	train-rmse:0.00518	eval-rmse:0.00867
# [61]	train-rmse:0.00516	eval-rmse:0.00867
# [62]	train-rmse:0.00513	eval-rmse:0.00866
# [63]	train-rmse:0.00511	eval-rmse:0.00865
# [64]	train-rmse:0.00510	eval-rmse:0.00865
# [65]	train-rmse:0.00509	eval-rmse:0.00865
# [66]	train-rmse:0.00506	eval-rmse:0.00865
# [67]	train-rmse:0.00506	eval-rmse:0.00865
# [68]	train-rmse:0.00505	eval-rmse:0.00865
# [69]	train-rmse:0.00502	eval-rmse:0.00865
# [70]	train-rmse:0.00501	eval-rmse:0.00866
# [71]	train-rmse:0.00500	eval-rmse:0.00866
# [72]	train-rmse:0.00500	eval-rmse:0.00866
# [73]	train-rmse:0.00499	eval-rmse:0.00866
# [74]	train-rmse:0.00498	eval-rmse:0.00866
# [75]	train-rmse:0.00497	eval-rmse:0.00866
# [76]	train-rmse:0.00497	eval-rmse:0.00866
# [77]	train-rmse:0.00495	eval-rmse:0.00866
# [78]	train-rmse:0.00494	eval-rmse:0.00865
# [79]	train-rmse:0.00493	eval-rmse:0.00866
# [80]	train-rmse:0.00492	eval-rmse:0.00866
# [81]	train-rmse:0.00490	eval-rmse:0.00866
# [82]	train-rmse:0.00489	eval-rmse:0.00866
# [83]	train-rmse:0.00487	eval-rmse:0.00866
# [84]	train-rmse:0.00485	eval-rmse:0.00866
# [85]	train-rmse:0.00484	eval-rmse:0.00866
# [86]	train-rmse:0.00481	eval-rmse:0.00866
# [87]	train-rmse:0.00479	eval-rmse:0.00866
# [88]	train-rmse:0.00476	eval-rmse:0.00865
# [89]	train-rmse:0.00475	eval-rmse:0.00864
# [90]	train-rmse:0.00475	eval-rmse:0.00864
# [91]	train-rmse:0.00474	eval-rmse:0.00864
# [92]	train-rmse:0.00473	eval-rmse:0.00865
# [93]	train-rmse:0.00471	eval-rmse:0.00865
# [94]	train-rmse:0.00469	eval-rmse:0.00865
# [95]	train-rmse:0.00468	eval-rmse:0.00865
# [96]	train-rmse:0.00467	eval-rmse:0.00865
# [97]	train-rmse:0.00464	eval-rmse:0.00864
# [98]	train-rmse:0.00463	eval-rmse:0.00864
# [99]	train-rmse:0.00461	eval-rmse:0.00864
# [100]	train-rmse:0.00461	eval-rmse:0.00865
# [101]	train-rmse:0.00459	eval-rmse:0.00864
# [102]	train-rmse:0.00458	eval-rmse:0.00864
# [103]	train-rmse:0.00457	eval-rmse:0.00865
# [104]	train-rmse:0.00456	eval-rmse:0.00865
# [105]	train-rmse:0.00456	eval-rmse:0.00865
# [106]	train-rmse:0.00454	eval-rmse:0.00865
# [107]	train-rmse:0.00454	eval-rmse:0.00865
# [108]	train-rmse:0.00453	eval-rmse:0.00865
# [109]	train-rmse:0.00452	eval-rmse:0.00865
# [110]	train-rmse:0.00451	eval-rmse:0.00865
# [111]	train-rmse:0.00450	eval-rmse:0.00864
# [112]	train-rmse:0.00448	eval-rmse:0.00864
# [113]	train-rmse:0.00447	eval-rmse:0.00864
# [114]	train-rmse:0.00445	eval-rmse:0.00864
# [115]	train-rmse:0.00444	eval-rmse:0.00864
# [116]	train-rmse:0.00443	eval-rmse:0.00863
# [117]	train-rmse:0.00442	eval-rmse:0.00863
# [118]	train-rmse:0.00441	eval-rmse:0.00863
# [119]	train-rmse:0.00441	eval-rmse:0.00863
# [120]	train-rmse:0.00441	eval-rmse:0.00863
# [121]	train-rmse:0.00440	eval-rmse:0.00863
# [122]	train-rmse:0.00440	eval-rmse:0.00863
# [123]	train-rmse:0.00440	eval-rmse:0.00863
# [124]	train-rmse:0.00439	eval-rmse:0.00863
# [125]	train-rmse:0.00437	eval-rmse:0.00862
# [126]	train-rmse:0.00437	eval-rmse:0.00862
# [127]	train-rmse:0.00436	eval-rmse:0.00863
# [128]	train-rmse:0.00435	eval-rmse:0.00863
# [129]	train-rmse:0.00434	eval-rmse:0.00864
# [130]	train-rmse:0.00433	eval-rmse:0.00864
# [131]	train-rmse:0.00433	eval-rmse:0.00864
# [132]	train-rmse:0.00432	eval-rmse:0.00864
# [133]	train-rmse:0.00431	eval-rmse:0.00863
# [134]	train-rmse:0.00430	eval-rmse:0.00863
# [135]	train-rmse:0.00429	eval-rmse:0.00863
# [136]	train-rmse:0.00428	eval-rmse:0.00863
# [137]	train-rmse:0.00427	eval-rmse:0.00863
# [138]	train-rmse:0.00426	eval-rmse:0.00864
# [139]	train-rmse:0.00425	eval-rmse:0.00864
# [140]	train-rmse:0.00423	eval-rmse:0.00864
# [141]	train-rmse:0.00422	eval-rmse:0.00864
# [142]	train-rmse:0.00421	eval-rmse:0.00863
# [143]	train-rmse:0.00420	eval-rmse:0.00863
# [144]	train-rmse:0.00418	eval-rmse:0.00863
# [145]	train-rmse:0.00417	eval-rmse:0.00863
# [146]	train-rmse:0.00416	eval-rmse:0.00862
# [147]	train-rmse:0.00415	eval-rmse:0.00862
# [148]	train-rmse:0.00414	eval-rmse:0.00862
# [149]	train-rmse:0.00413	eval-rmse:0.00862
# [150]	train-rmse:0.00413	eval-rmse:0.00862
# [151]	train-rmse:0.00412	eval-rmse:0.00861
# [152]	train-rmse:0.00411	eval-rmse:0.00861
# [153]	train-rmse:0.00411	eval-rmse:0.00861
# [154]	train-rmse:0.00410	eval-rmse:0.00862
# [155]	train-rmse:0.00409	eval-rmse:0.00862
# [156]	train-rmse:0.00408	eval-rmse:0.00862
# [157]	train-rmse:0.00407	eval-rmse:0.00861
# [158]	train-rmse:0.00406	eval-rmse:0.00861
# [159]	train-rmse:0.00406	eval-rmse:0.00861
# [160]	train-rmse:0.00405	eval-rmse:0.00862
# [161]	train-rmse:0.00404	eval-rmse:0.00861
# [162]	train-rmse:0.00404	eval-rmse:0.00862
# [163]	train-rmse:0.00402	eval-rmse:0.00861
# [164]	train-rmse:0.00401	eval-rmse:0.00861
# [165]	train-rmse:0.00400	eval-rmse:0.00861
# [166]	train-rmse:0.00399	eval-rmse:0.00861
# [167]	train-rmse:0.00399	eval-rmse:0.00861
# [168]	train-rmse:0.00398	eval-rmse:0.00861
# [169]	train-rmse:0.00398	eval-rmse:0.00861
# [170]	train-rmse:0.00398	eval-rmse:0.00862
# [171]	train-rmse:0.00398	eval-rmse:0.00862
# [172]	train-rmse:0.00397	eval-rmse:0.00861
# [173]	train-rmse:0.00397	eval-rmse:0.00862
# [174]	train-rmse:0.00396	eval-rmse:0.00862
# [175]	train-rmse:0.00396	eval-rmse:0.00862
# [176]	train-rmse:0.00395	eval-rmse:0.00862
# [177]	train-rmse:0.00394	eval-rmse:0.00862
# [178]	train-rmse:0.00393	eval-rmse:0.00861
# [179]	train-rmse:0.00393	eval-rmse:0.00861
# [180]	train-rmse:0.00392	eval-rmse:0.00861
# [181]	train-rmse:0.00392	eval-rmse:0.00861
# [182]	train-rmse:0.00391	eval-rmse:0.00861
# [183]	train-rmse:0.00390	eval-rmse:0.00861
# [184]	train-rmse:0.00390	eval-rmse:0.00861
# [185]	train-rmse:0.00390	eval-rmse:0.00861
# [186]	train-rmse:0.00389	eval-rmse:0.00861
# [187]	train-rmse:0.00389	eval-rmse:0.00861
# [188]	train-rmse:0.00388	eval-rmse:0.00861
# [189]	train-rmse:0.00388	eval-rmse:0.00860
# [190]	train-rmse:0.00387	eval-rmse:0.00861
# [191]	train-rmse:0.00386	eval-rmse:0.00860
# [192]	train-rmse:0.00385	eval-rmse:0.00860
# [193]	train-rmse:0.00385	eval-rmse:0.00860
# [194]	train-rmse:0.00385	eval-rmse:0.00860
# [195]	train-rmse:0.00383	eval-rmse:0.00860
# [196]	train-rmse:0.00382	eval-rmse:0.00860
# [197]	train-rmse:0.00381	eval-rmse:0.00860
# [198]	train-rmse:0.00380	eval-rmse:0.00860
# [199]	train-rmse:0.00380	eval-rmse:0.00860
# [200]	train-rmse:0.00379	eval-rmse:0.00860
# [201]	train-rmse:0.00378	eval-rmse:0.00860
# [202]	train-rmse:0.00378	eval-rmse:0.00860
# [203]	train-rmse:0.00377	eval-rmse:0.00860
# [204]	train-rmse:0.00377	eval-rmse:0.00860
# [205]	train-rmse:0.00377	eval-rmse:0.00861
# [206]	train-rmse:0.00377	eval-rmse:0.00861
# [207]	train-rmse:0.00376	eval-rmse:0.00861
# [208]	train-rmse:0.00376	eval-rmse:0.00861
# [209]	train-rmse:0.00376	eval-rmse:0.00861
# [210]	train-rmse:0.00375	eval-rmse:0.00860
# [211]	train-rmse:0.00375	eval-rmse:0.00861
# [212]	train-rmse:0.00375	eval-rmse:0.00860
# [213]	train-rmse:0.00374	eval-rmse:0.00860
# [214]	train-rmse:0.00373	eval-rmse:0.00860
# [215]	train-rmse:0.00373	eval-rmse:0.00860
# [216]	train-rmse:0.00372	eval-rmse:0.00860
# [217]	train-rmse:0.00371	eval-rmse:0.00860
# [218]	train-rmse:0.00371	eval-rmse:0.00860
# [219]	train-rmse:0.00370	eval-rmse:0.00860
# [220]	train-rmse:0.00370	eval-rmse:0.00860
# [221]	train-rmse:0.00369	eval-rmse:0.00860
# [222]	train-rmse:0.00369	eval-rmse:0.00860
# [223]	train-rmse:0.00368	eval-rmse:0.00860
# [224]	train-rmse:0.00367	eval-rmse:0.00860
# [225]	train-rmse:0.00367	eval-rmse:0.00860
# [226]	train-rmse:0.00366	eval-rmse:0.00860
# [227]	train-rmse:0.00365	eval-rmse:0.00861
# [228]	train-rmse:0.00364	eval-rmse:0.00861
# [229]	train-rmse:0.00364	eval-rmse:0.00861
# [230]	train-rmse:0.00363	eval-rmse:0.00861
# [231]	train-rmse:0.00363	eval-rmse:0.00860
# [232]	train-rmse:0.00362	eval-rmse:0.00860
# [233]	train-rmse:0.00361	eval-rmse:0.00860
# [234]	train-rmse:0.00361	eval-rmse:0.00861
# [235]	train-rmse:0.00360	eval-rmse:0.00860
# [236]	train-rmse:0.00360	eval-rmse:0.00860
# [237]	train-rmse:0.00360	eval-rmse:0.00860
# [238]	train-rmse:0.00359	eval-rmse:0.00860
# [239]	train-rmse:0.00358	eval-rmse:0.00860
# [240]	train-rmse:0.00358	eval-rmse:0.00860
# [241]	train-rmse:0.00357	eval-rmse:0.00860
# [242]	train-rmse:0.00356	eval-rmse:0.00860
# [243]	train-rmse:0.00355	eval-rmse:0.00860
# [244]	train-rmse:0.00354	eval-rmse:0.00860
# [245]	train-rmse:0.00353	eval-rmse:0.00860
# [246]	train-rmse:0.00353	eval-rmse:0.00861
# [247]	train-rmse:0.00352	eval-rmse:0.00861
# seed1999, fold2, score [0.999200988398228]
# [12:55:51] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-rmse:0.17710	eval-rmse:0.17758
# [1]	train-rmse:0.12464	eval-rmse:0.12516
# [2]	train-rmse:0.08785	eval-rmse:0.08844
# [3]	train-rmse:0.06211	eval-rmse:0.06273
# [4]	train-rmse:0.04414	eval-rmse:0.04481
# [5]	train-rmse:0.03161	eval-rmse:0.03243
# [6]	train-rmse:0.02294	eval-rmse:0.02390
# [7]	train-rmse:0.01704	eval-rmse:0.01822
# [8]	train-rmse:0.01315	eval-rmse:0.01458
# [9]	train-rmse:0.01065	eval-rmse:0.01231
# [10]	train-rmse:0.00909	eval-rmse:0.01095
# [11]	train-rmse:0.00812	eval-rmse:0.01013
# [12]	train-rmse:0.00757	eval-rmse:0.00971
# [13]	train-rmse:0.00725	eval-rmse:0.00947
# [14]	train-rmse:0.00703	eval-rmse:0.00930
# [15]	train-rmse:0.00689	eval-rmse:0.00921
# [16]	train-rmse:0.00677	eval-rmse:0.00914
# [17]	train-rmse:0.00669	eval-rmse:0.00912
# [18]	train-rmse:0.00657	eval-rmse:0.00905
# [19]	train-rmse:0.00651	eval-rmse:0.00903
# [20]	train-rmse:0.00644	eval-rmse:0.00899
# [21]	train-rmse:0.00641	eval-rmse:0.00899
# [22]	train-rmse:0.00633	eval-rmse:0.00894
# [23]	train-rmse:0.00631	eval-rmse:0.00894
# [24]	train-rmse:0.00628	eval-rmse:0.00893
# [25]	train-rmse:0.00624	eval-rmse:0.00893
# [26]	train-rmse:0.00622	eval-rmse:0.00893
# [27]	train-rmse:0.00619	eval-rmse:0.00893
# [28]	train-rmse:0.00618	eval-rmse:0.00893
# [29]	train-rmse:0.00616	eval-rmse:0.00891
# [30]	train-rmse:0.00609	eval-rmse:0.00887
# [31]	train-rmse:0.00603	eval-rmse:0.00885
# [32]	train-rmse:0.00600	eval-rmse:0.00883
# [33]	train-rmse:0.00593	eval-rmse:0.00881
# [34]	train-rmse:0.00589	eval-rmse:0.00879
# [35]	train-rmse:0.00588	eval-rmse:0.00879
# [36]	train-rmse:0.00587	eval-rmse:0.00879
# [37]	train-rmse:0.00581	eval-rmse:0.00876
# [38]	train-rmse:0.00578	eval-rmse:0.00874
# [39]	train-rmse:0.00576	eval-rmse:0.00873
# [40]	train-rmse:0.00572	eval-rmse:0.00872
# [41]	train-rmse:0.00569	eval-rmse:0.00872
# [42]	train-rmse:0.00568	eval-rmse:0.00872
# [43]	train-rmse:0.00567	eval-rmse:0.00871
# [44]	train-rmse:0.00566	eval-rmse:0.00871
# [45]	train-rmse:0.00564	eval-rmse:0.00870
# [46]	train-rmse:0.00559	eval-rmse:0.00871
# [47]	train-rmse:0.00557	eval-rmse:0.00870
# [48]	train-rmse:0.00554	eval-rmse:0.00870
# [49]	train-rmse:0.00551	eval-rmse:0.00870
# [50]	train-rmse:0.00549	eval-rmse:0.00870
# [51]	train-rmse:0.00547	eval-rmse:0.00871
# [52]	train-rmse:0.00544	eval-rmse:0.00870
# [53]	train-rmse:0.00544	eval-rmse:0.00870
# [54]	train-rmse:0.00543	eval-rmse:0.00870
# [55]	train-rmse:0.00543	eval-rmse:0.00870
# [56]	train-rmse:0.00542	eval-rmse:0.00870
# [57]	train-rmse:0.00539	eval-rmse:0.00868
# [58]	train-rmse:0.00535	eval-rmse:0.00869
# [59]	train-rmse:0.00533	eval-rmse:0.00868
# [60]	train-rmse:0.00531	eval-rmse:0.00869
# [61]	train-rmse:0.00528	eval-rmse:0.00869
# [62]	train-rmse:0.00525	eval-rmse:0.00868
# [63]	train-rmse:0.00522	eval-rmse:0.00867
# [64]	train-rmse:0.00521	eval-rmse:0.00867
# [65]	train-rmse:0.00518	eval-rmse:0.00866
# [66]	train-rmse:0.00515	eval-rmse:0.00865
# [67]	train-rmse:0.00513	eval-rmse:0.00865
# [68]	train-rmse:0.00512	eval-rmse:0.00866
# [69]	train-rmse:0.00512	eval-rmse:0.00866
# [70]	train-rmse:0.00510	eval-rmse:0.00865
# [71]	train-rmse:0.00510	eval-rmse:0.00865
# [72]	train-rmse:0.00509	eval-rmse:0.00865
# [73]	train-rmse:0.00508	eval-rmse:0.00865
# [74]	train-rmse:0.00507	eval-rmse:0.00865
# [75]	train-rmse:0.00506	eval-rmse:0.00866
# [76]	train-rmse:0.00505	eval-rmse:0.00866
# [77]	train-rmse:0.00504	eval-rmse:0.00866
# [78]	train-rmse:0.00502	eval-rmse:0.00866
# [79]	train-rmse:0.00501	eval-rmse:0.00866
# [80]	train-rmse:0.00499	eval-rmse:0.00866
# [81]	train-rmse:0.00497	eval-rmse:0.00865
# [82]	train-rmse:0.00494	eval-rmse:0.00866
# [83]	train-rmse:0.00491	eval-rmse:0.00865
# [84]	train-rmse:0.00490	eval-rmse:0.00865
# [85]	train-rmse:0.00490	eval-rmse:0.00865
# [86]	train-rmse:0.00486	eval-rmse:0.00865
# [87]	train-rmse:0.00485	eval-rmse:0.00865
# [88]	train-rmse:0.00483	eval-rmse:0.00865
# [89]	train-rmse:0.00482	eval-rmse:0.00865
# [90]	train-rmse:0.00482	eval-rmse:0.00865
# [91]	train-rmse:0.00480	eval-rmse:0.00865
# [92]	train-rmse:0.00478	eval-rmse:0.00864
# [93]	train-rmse:0.00475	eval-rmse:0.00864
# [94]	train-rmse:0.00474	eval-rmse:0.00863
# [95]	train-rmse:0.00473	eval-rmse:0.00863
# [96]	train-rmse:0.00472	eval-rmse:0.00863
# [97]	train-rmse:0.00471	eval-rmse:0.00863
# [98]	train-rmse:0.00470	eval-rmse:0.00864
# [99]	train-rmse:0.00470	eval-rmse:0.00864
# [100]	train-rmse:0.00469	eval-rmse:0.00864
# [101]	train-rmse:0.00467	eval-rmse:0.00864
# [102]	train-rmse:0.00466	eval-rmse:0.00864
# [103]	train-rmse:0.00465	eval-rmse:0.00864
# [104]	train-rmse:0.00464	eval-rmse:0.00864
# [105]	train-rmse:0.00462	eval-rmse:0.00864
# [106]	train-rmse:0.00461	eval-rmse:0.00864
# [107]	train-rmse:0.00460	eval-rmse:0.00863
# [108]	train-rmse:0.00459	eval-rmse:0.00864
# [109]	train-rmse:0.00457	eval-rmse:0.00864
# [110]	train-rmse:0.00456	eval-rmse:0.00864
# [111]	train-rmse:0.00455	eval-rmse:0.00864
# [112]	train-rmse:0.00454	eval-rmse:0.00864
# [113]	train-rmse:0.00453	eval-rmse:0.00864
# [114]	train-rmse:0.00452	eval-rmse:0.00864
# [115]	train-rmse:0.00450	eval-rmse:0.00863
# [116]	train-rmse:0.00449	eval-rmse:0.00864
# [117]	train-rmse:0.00447	eval-rmse:0.00864
# [118]	train-rmse:0.00447	eval-rmse:0.00864
# [119]	train-rmse:0.00446	eval-rmse:0.00864
# [120]	train-rmse:0.00445	eval-rmse:0.00864
# [121]	train-rmse:0.00444	eval-rmse:0.00864
# [122]	train-rmse:0.00443	eval-rmse:0.00864
# [123]	train-rmse:0.00443	eval-rmse:0.00863
# [124]	train-rmse:0.00441	eval-rmse:0.00863
# [125]	train-rmse:0.00439	eval-rmse:0.00863
# [126]	train-rmse:0.00438	eval-rmse:0.00863
# [127]	train-rmse:0.00437	eval-rmse:0.00863
# [128]	train-rmse:0.00435	eval-rmse:0.00863
# [129]	train-rmse:0.00435	eval-rmse:0.00863
# [130]	train-rmse:0.00434	eval-rmse:0.00863
# [131]	train-rmse:0.00434	eval-rmse:0.00863
# [132]	train-rmse:0.00432	eval-rmse:0.00863
# [133]	train-rmse:0.00432	eval-rmse:0.00863
# [134]	train-rmse:0.00430	eval-rmse:0.00864
# [135]	train-rmse:0.00430	eval-rmse:0.00864
# [136]	train-rmse:0.00429	eval-rmse:0.00863
# [137]	train-rmse:0.00428	eval-rmse:0.00863
# [138]	train-rmse:0.00427	eval-rmse:0.00863
# [139]	train-rmse:0.00427	eval-rmse:0.00863
# [140]	train-rmse:0.00426	eval-rmse:0.00863
# [141]	train-rmse:0.00425	eval-rmse:0.00863
# [142]	train-rmse:0.00421	eval-rmse:0.00862
# [143]	train-rmse:0.00421	eval-rmse:0.00862
# [144]	train-rmse:0.00419	eval-rmse:0.00862
# [145]	train-rmse:0.00417	eval-rmse:0.00862
# [146]	train-rmse:0.00416	eval-rmse:0.00861
# [147]	train-rmse:0.00414	eval-rmse:0.00861
# [148]	train-rmse:0.00413	eval-rmse:0.00861
# [149]	train-rmse:0.00413	eval-rmse:0.00861
# [150]	train-rmse:0.00411	eval-rmse:0.00861
# [151]	train-rmse:0.00411	eval-rmse:0.00861
# [152]	train-rmse:0.00410	eval-rmse:0.00860
# [153]	train-rmse:0.00408	eval-rmse:0.00860
# [154]	train-rmse:0.00407	eval-rmse:0.00860
# [155]	train-rmse:0.00406	eval-rmse:0.00860
# [156]	train-rmse:0.00405	eval-rmse:0.00860
# [157]	train-rmse:0.00404	eval-rmse:0.00860
# [158]	train-rmse:0.00404	eval-rmse:0.00860
# [159]	train-rmse:0.00402	eval-rmse:0.00860
# [160]	train-rmse:0.00401	eval-rmse:0.00859
# [161]	train-rmse:0.00400	eval-rmse:0.00859
# [162]	train-rmse:0.00399	eval-rmse:0.00859
# [163]	train-rmse:0.00398	eval-rmse:0.00859
# [164]	train-rmse:0.00397	eval-rmse:0.00859
# [165]	train-rmse:0.00397	eval-rmse:0.00859
# [166]	train-rmse:0.00395	eval-rmse:0.00859
# [167]	train-rmse:0.00395	eval-rmse:0.00859
# [168]	train-rmse:0.00394	eval-rmse:0.00859
# [169]	train-rmse:0.00393	eval-rmse:0.00859
# [170]	train-rmse:0.00392	eval-rmse:0.00860
# [171]	train-rmse:0.00392	eval-rmse:0.00860
# [172]	train-rmse:0.00392	eval-rmse:0.00860
# [173]	train-rmse:0.00391	eval-rmse:0.00860
# [174]	train-rmse:0.00390	eval-rmse:0.00860
# [175]	train-rmse:0.00390	eval-rmse:0.00860
# [176]	train-rmse:0.00389	eval-rmse:0.00860
# [177]	train-rmse:0.00389	eval-rmse:0.00860
# [178]	train-rmse:0.00388	eval-rmse:0.00860
# [179]	train-rmse:0.00387	eval-rmse:0.00860
# [180]	train-rmse:0.00387	eval-rmse:0.00860
# [181]	train-rmse:0.00386	eval-rmse:0.00860
# [182]	train-rmse:0.00386	eval-rmse:0.00860
# [183]	train-rmse:0.00385	eval-rmse:0.00860
# [184]	train-rmse:0.00385	eval-rmse:0.00860
# [185]	train-rmse:0.00385	eval-rmse:0.00860
# [186]	train-rmse:0.00384	eval-rmse:0.00860
# [187]	train-rmse:0.00384	eval-rmse:0.00860
# [188]	train-rmse:0.00384	eval-rmse:0.00860
# [189]	train-rmse:0.00382	eval-rmse:0.00860
# [190]	train-rmse:0.00381	eval-rmse:0.00860
# [191]	train-rmse:0.00381	eval-rmse:0.00860
# [192]	train-rmse:0.00380	eval-rmse:0.00860
# [193]	train-rmse:0.00380	eval-rmse:0.00860
# [194]	train-rmse:0.00379	eval-rmse:0.00860
# [195]	train-rmse:0.00379	eval-rmse:0.00860
# [196]	train-rmse:0.00378	eval-rmse:0.00860
# [197]	train-rmse:0.00377	eval-rmse:0.00860
# [198]	train-rmse:0.00376	eval-rmse:0.00860
# [199]	train-rmse:0.00375	eval-rmse:0.00860
# [200]	train-rmse:0.00374	eval-rmse:0.00860
# [201]	train-rmse:0.00373	eval-rmse:0.00860
# [202]	train-rmse:0.00372	eval-rmse:0.00860
# [203]	train-rmse:0.00372	eval-rmse:0.00860
# [204]	train-rmse:0.00371	eval-rmse:0.00860
# [205]	train-rmse:0.00371	eval-rmse:0.00860
# [206]	train-rmse:0.00370	eval-rmse:0.00860
# [207]	train-rmse:0.00369	eval-rmse:0.00860
# [208]	train-rmse:0.00369	eval-rmse:0.00860
# [209]	train-rmse:0.00368	eval-rmse:0.00860
# [210]	train-rmse:0.00368	eval-rmse:0.00860
# [211]	train-rmse:0.00367	eval-rmse:0.00860
# [212]	train-rmse:0.00367	eval-rmse:0.00860
# seed1999, fold3, score [0.9991618528880426]
# [12:58:14] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-rmse:0.17744	eval-rmse:0.17661
# [1]	train-rmse:0.12484	eval-rmse:0.12442
# [2]	train-rmse:0.08799	eval-rmse:0.08791
# [3]	train-rmse:0.06220	eval-rmse:0.06235
# [4]	train-rmse:0.04413	eval-rmse:0.04457
# [5]	train-rmse:0.03156	eval-rmse:0.03234
# [6]	train-rmse:0.02285	eval-rmse:0.02402
# [7]	train-rmse:0.01692	eval-rmse:0.01851
# [8]	train-rmse:0.01298	eval-rmse:0.01500
# [9]	train-rmse:0.01044	eval-rmse:0.01288
# [10]	train-rmse:0.00886	eval-rmse:0.01163
# [11]	train-rmse:0.00792	eval-rmse:0.01091
# [12]	train-rmse:0.00737	eval-rmse:0.01053
# [13]	train-rmse:0.00702	eval-rmse:0.01028
# [14]	train-rmse:0.00677	eval-rmse:0.01009
# [15]	train-rmse:0.00661	eval-rmse:0.01002
# [16]	train-rmse:0.00651	eval-rmse:0.00996
# [17]	train-rmse:0.00639	eval-rmse:0.00989
# [18]	train-rmse:0.00633	eval-rmse:0.00985
# [19]	train-rmse:0.00626	eval-rmse:0.00983
# [20]	train-rmse:0.00621	eval-rmse:0.00980
# [21]	train-rmse:0.00613	eval-rmse:0.00976
# [22]	train-rmse:0.00610	eval-rmse:0.00975
# [23]	train-rmse:0.00604	eval-rmse:0.00973
# [24]	train-rmse:0.00602	eval-rmse:0.00973
# [25]	train-rmse:0.00596	eval-rmse:0.00971
# [26]	train-rmse:0.00593	eval-rmse:0.00970
# [27]	train-rmse:0.00588	eval-rmse:0.00966
# [28]	train-rmse:0.00583	eval-rmse:0.00963
# [29]	train-rmse:0.00583	eval-rmse:0.00963
# [30]	train-rmse:0.00580	eval-rmse:0.00963
# [31]	train-rmse:0.00577	eval-rmse:0.00963
# [32]	train-rmse:0.00574	eval-rmse:0.00962
# [33]	train-rmse:0.00568	eval-rmse:0.00960
# [34]	train-rmse:0.00566	eval-rmse:0.00959
# [35]	train-rmse:0.00561	eval-rmse:0.00956
# [36]	train-rmse:0.00556	eval-rmse:0.00951
# [37]	train-rmse:0.00552	eval-rmse:0.00950
# [38]	train-rmse:0.00546	eval-rmse:0.00948
# [39]	train-rmse:0.00543	eval-rmse:0.00946
# [40]	train-rmse:0.00541	eval-rmse:0.00946
# [41]	train-rmse:0.00537	eval-rmse:0.00944
# [42]	train-rmse:0.00534	eval-rmse:0.00943
# [43]	train-rmse:0.00534	eval-rmse:0.00942
# [44]	train-rmse:0.00530	eval-rmse:0.00940
# ...
# [97]	train-rmse:0.00464	eval-rmse:0.00864
# [98]	train-rmse:0.00463	eval-rmse:0.00864
# [99]	train-rmse:0.00461	eval-rmse:0.00864
# [100]	train-rmse:0.00461	eval-rmse:0.00865
# [101]	train-rmse:0.00459	eval-rmse:0.00864
# [102]	train-rmse:0.00458	eval-rmse:0.00864
# [103]	train-rmse:0.00457	eval-rmse:0.00865
# [104]	train-rmse:0.00456	eval-rmse:0.00865
# [105]	train-rmse:0.00456	eval-rmse:0.00865
# [106]	train-rmse:0.00454	eval-rmse:0.00865
# [107]	train-rmse:0.00454	eval-rmse:0.00865
# [108]	train-rmse:0.00453	eval-rmse:0.00865
# [109]	train-rmse:0.00452	eval-rmse:0.00865
# [110]	train-rmse:0.00451	eval-rmse:0.00865
# [111]	train-rmse:0.00450	eval-rmse:0.00864
# [112]	train-rmse:0.00448	eval-rmse:0.00864
# [113]	train-rmse:0.00447	eval-rmse:0.00864
# [114]	train-rmse:0.00445	eval-rmse:0.00864
# [115]	train-rmse:0.00444	eval-rmse:0.00864
# [116]	train-rmse:0.00443	eval-rmse:0.00863
# [117]	train-rmse:0.00442	eval-rmse:0.00863
# [118]	train-rmse:0.00441	eval-rmse:0.00863
# [119]	train-rmse:0.00441	eval-rmse:0.00863
# [120]	train-rmse:0.00441	eval-rmse:0.00863
# [121]	train-rmse:0.00440	eval-rmse:0.00863
# [122]	train-rmse:0.00440	eval-rmse:0.00863
# [123]	train-rmse:0.00440	eval-rmse:0.00863
# [124]	train-rmse:0.00439	eval-rmse:0.00863
# [125]	train-rmse:0.00437	eval-rmse:0.00862
# [126]	train-rmse:0.00437	eval-rmse:0.00862
# [127]	train-rmse:0.00436	eval-rmse:0.00863
# [128]	train-rmse:0.00435	eval-rmse:0.00863
# [129]	train-rmse:0.00434	eval-rmse:0.00864
# [130]	train-rmse:0.00433	eval-rmse:0.00864
# [131]	train-rmse:0.00433	eval-rmse:0.00864
# [132]	train-rmse:0.00432	eval-rmse:0.00864
# [133]	train-rmse:0.00431	eval-rmse:0.00863
# [134]	train-rmse:0.00430	eval-rmse:0.00863
# [135]	train-rmse:0.00429	eval-rmse:0.00863
# [136]	train-rmse:0.00428	eval-rmse:0.00863
# [137]	train-rmse:0.00427	eval-rmse:0.00863
# [138]	train-rmse:0.00426	eval-rmse:0.00864
# [139]	train-rmse:0.00425	eval-rmse:0.00864
# [140]	train-rmse:0.00423	eval-rmse:0.00864
# [141]	train-rmse:0.00422	eval-rmse:0.00864
# [142]	train-rmse:0.00421	eval-rmse:0.00863
# [143]	train-rmse:0.00420	eval-rmse:0.00863
# [144]	train-rmse:0.00418	eval-rmse:0.00863
# [145]	train-rmse:0.00417	eval-rmse:0.00863
# [146]	train-rmse:0.00416	eval-rmse:0.00862
# [147]	train-rmse:0.00415	eval-rmse:0.00862
# [148]	train-rmse:0.00414	eval-rmse:0.00862
# [149]	train-rmse:0.00413	eval-rmse:0.00862
# [150]	train-rmse:0.00413	eval-rmse:0.00862
# [151]	train-rmse:0.00412	eval-rmse:0.00861
# [152]	train-rmse:0.00411	eval-rmse:0.00861
# [153]	train-rmse:0.00411	eval-rmse:0.00861
# [154]	train-rmse:0.00410	eval-rmse:0.00862
# [155]	train-rmse:0.00409	eval-rmse:0.00862
# [156]	train-rmse:0.00408	eval-rmse:0.00862
# [157]	train-rmse:0.00407	eval-rmse:0.00861
# [158]	train-rmse:0.00406	eval-rmse:0.00861
# [159]	train-rmse:0.00406	eval-rmse:0.00861
# [160]	train-rmse:0.00405	eval-rmse:0.00862
# [161]	train-rmse:0.00404	eval-rmse:0.00861
# [162]	train-rmse:0.00404	eval-rmse:0.00862
# [163]	train-rmse:0.00402	eval-rmse:0.00861
# [164]	train-rmse:0.00401	eval-rmse:0.00861
# [165]	train-rmse:0.00400	eval-rmse:0.00861
# [166]	train-rmse:0.00399	eval-rmse:0.00861
# [167]	train-rmse:0.00399	eval-rmse:0.00861
# [168]	train-rmse:0.00398	eval-rmse:0.00861
# [169]	train-rmse:0.00398	eval-rmse:0.00861
# [170]	train-rmse:0.00398	eval-rmse:0.00862
# [171]	train-rmse:0.00398	eval-rmse:0.00862
# [172]	train-rmse:0.00397	eval-rmse:0.00861
# [173]	train-rmse:0.00397	eval-rmse:0.00862
# [174]	train-rmse:0.00396	eval-rmse:0.00862
# [175]	train-rmse:0.00396	eval-rmse:0.00862
# [176]	train-rmse:0.00395	eval-rmse:0.00862
# [177]	train-rmse:0.00394	eval-rmse:0.00862
# [178]	train-rmse:0.00393	eval-rmse:0.00861
# [179]	train-rmse:0.00393	eval-rmse:0.00861
# [180]	train-rmse:0.00392	eval-rmse:0.00861
# [181]	train-rmse:0.00392	eval-rmse:0.00861
# [182]	train-rmse:0.00391	eval-rmse:0.00861
# [183]	train-rmse:0.00390	eval-rmse:0.00861
# [184]	train-rmse:0.00390	eval-rmse:0.00861
# [185]	train-rmse:0.00390	eval-rmse:0.00861
# [186]	train-rmse:0.00389	eval-rmse:0.00861
# [187]	train-rmse:0.00389	eval-rmse:0.00861
# [188]	train-rmse:0.00388	eval-rmse:0.00861
# [189]	train-rmse:0.00388	eval-rmse:0.00860
# [190]	train-rmse:0.00387	eval-rmse:0.00861
# [191]	train-rmse:0.00386	eval-rmse:0.00860
# [192]	train-rmse:0.00385	eval-rmse:0.00860
# [193]	train-rmse:0.00385	eval-rmse:0.00860
# [194]	train-rmse:0.00385	eval-rmse:0.00860
# [195]	train-rmse:0.00383	eval-rmse:0.00860
# [196]	train-rmse:0.00382	eval-rmse:0.00860
# [197]	train-rmse:0.00381	eval-rmse:0.00860
# [198]	train-rmse:0.00380	eval-rmse:0.00860
# [199]	train-rmse:0.00380	eval-rmse:0.00860
# [200]	train-rmse:0.00379	eval-rmse:0.00860
# [201]	train-rmse:0.00378	eval-rmse:0.00860
# [202]	train-rmse:0.00378	eval-rmse:0.00860
# [203]	train-rmse:0.00377	eval-rmse:0.00860
# [204]	train-rmse:0.00377	eval-rmse:0.00860
# [205]	train-rmse:0.00377	eval-rmse:0.00861
# [206]	train-rmse:0.00377	eval-rmse:0.00861
# [207]	train-rmse:0.00376	eval-rmse:0.00861
# [208]	train-rmse:0.00376	eval-rmse:0.00861
# [209]	train-rmse:0.00376	eval-rmse:0.00861
# [210]	train-rmse:0.00375	eval-rmse:0.00860
# [211]	train-rmse:0.00375	eval-rmse:0.00861
# [212]	train-rmse:0.00375	eval-rmse:0.00860
# [213]	train-rmse:0.00374	eval-rmse:0.00860
# [214]	train-rmse:0.00373	eval-rmse:0.00860
# [215]	train-rmse:0.00373	eval-rmse:0.00860
# [216]	train-rmse:0.00372	eval-rmse:0.00860
# [217]	train-rmse:0.00371	eval-rmse:0.00860
# [218]	train-rmse:0.00371	eval-rmse:0.00860
# [219]	train-rmse:0.00370	eval-rmse:0.00860
# [220]	train-rmse:0.00370	eval-rmse:0.00860
# [221]	train-rmse:0.00369	eval-rmse:0.00860
# [222]	train-rmse:0.00369	eval-rmse:0.00860
# [223]	train-rmse:0.00368	eval-rmse:0.00860
# [224]	train-rmse:0.00367	eval-rmse:0.00860
# [225]	train-rmse:0.00367	eval-rmse:0.00860
# [226]	train-rmse:0.00366	eval-rmse:0.00860
# [227]	train-rmse:0.00365	eval-rmse:0.00861
# [228]	train-rmse:0.00364	eval-rmse:0.00861
# [229]	train-rmse:0.00364	eval-rmse:0.00861
# [230]	train-rmse:0.00363	eval-rmse:0.00861
# [231]	train-rmse:0.00363	eval-rmse:0.00860
# [232]	train-rmse:0.00362	eval-rmse:0.00860
# [233]	train-rmse:0.00361	eval-rmse:0.00860
# [234]	train-rmse:0.00361	eval-rmse:0.00861
# [235]	train-rmse:0.00360	eval-rmse:0.00860
# [236]	train-rmse:0.00360	eval-rmse:0.00860
# [237]	train-rmse:0.00360	eval-rmse:0.00860
# [238]	train-rmse:0.00359	eval-rmse:0.00860
# [239]	train-rmse:0.00358	eval-rmse:0.00860
# [240]	train-rmse:0.00358	eval-rmse:0.00860
# [241]	train-rmse:0.00357	eval-rmse:0.00860
# [242]	train-rmse:0.00356	eval-rmse:0.00860
# [243]	train-rmse:0.00355	eval-rmse:0.00860
# [244]	train-rmse:0.00354	eval-rmse:0.00860
# [245]	train-rmse:0.00353	eval-rmse:0.00860
# [246]	train-rmse:0.00353	eval-rmse:0.00861
# [247]	train-rmse:0.00352	eval-rmse:0.00861
# seed2022, fold2, score [0.999200988398228]
# [13:16:31] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-rmse:0.17710	eval-rmse:0.17758
# [1]	train-rmse:0.12464	eval-rmse:0.12516
# [2]	train-rmse:0.08785	eval-rmse:0.08844
# [3]	train-rmse:0.06211	eval-rmse:0.06273
# [4]	train-rmse:0.04414	eval-rmse:0.04481
# [5]	train-rmse:0.03161	eval-rmse:0.03243
# [6]	train-rmse:0.02294	eval-rmse:0.02390
# [7]	train-rmse:0.01704	eval-rmse:0.01822
# [8]	train-rmse:0.01315	eval-rmse:0.01458
# [9]	train-rmse:0.01065	eval-rmse:0.01231
# [10]	train-rmse:0.00909	eval-rmse:0.01095
# [11]	train-rmse:0.00812	eval-rmse:0.01013
# [12]	train-rmse:0.00757	eval-rmse:0.00971
# [13]	train-rmse:0.00725	eval-rmse:0.00947
# [14]	train-rmse:0.00703	eval-rmse:0.00930
# [15]	train-rmse:0.00689	eval-rmse:0.00921
# [16]	train-rmse:0.00677	eval-rmse:0.00914
# [17]	train-rmse:0.00669	eval-rmse:0.00912
# [18]	train-rmse:0.00657	eval-rmse:0.00905
# [19]	train-rmse:0.00651	eval-rmse:0.00903
# [20]	train-rmse:0.00644	eval-rmse:0.00899
# [21]	train-rmse:0.00641	eval-rmse:0.00899
# [22]	train-rmse:0.00633	eval-rmse:0.00894
# [23]	train-rmse:0.00631	eval-rmse:0.00894
# [24]	train-rmse:0.00628	eval-rmse:0.00893
# [25]	train-rmse:0.00624	eval-rmse:0.00893
# [26]	train-rmse:0.00622	eval-rmse:0.00893
# [27]	train-rmse:0.00619	eval-rmse:0.00893
# [28]	train-rmse:0.00618	eval-rmse:0.00893
# [29]	train-rmse:0.00616	eval-rmse:0.00891
# [30]	train-rmse:0.00609	eval-rmse:0.00887
# [31]	train-rmse:0.00603	eval-rmse:0.00885
# [32]	train-rmse:0.00600	eval-rmse:0.00883
# [33]	train-rmse:0.00593	eval-rmse:0.00881
# [34]	train-rmse:0.00589	eval-rmse:0.00879
# [35]	train-rmse:0.00588	eval-rmse:0.00879
# [36]	train-rmse:0.00587	eval-rmse:0.00879
# [37]	train-rmse:0.00581	eval-rmse:0.00876
# [38]	train-rmse:0.00578	eval-rmse:0.00874
# [39]	train-rmse:0.00576	eval-rmse:0.00873
# [40]	train-rmse:0.00572	eval-rmse:0.00872
# [41]	train-rmse:0.00569	eval-rmse:0.00872
# [42]	train-rmse:0.00568	eval-rmse:0.00872
# [43]	train-rmse:0.00567	eval-rmse:0.00871
# [44]	train-rmse:0.00566	eval-rmse:0.00871
# [45]	train-rmse:0.00564	eval-rmse:0.00870
# [46]	train-rmse:0.00559	eval-rmse:0.00871
# [47]	train-rmse:0.00557	eval-rmse:0.00870
# [48]	train-rmse:0.00554	eval-rmse:0.00870
# [49]	train-rmse:0.00551	eval-rmse:0.00870
# [50]	train-rmse:0.00549	eval-rmse:0.00870
# [51]	train-rmse:0.00547	eval-rmse:0.00871
# [52]	train-rmse:0.00544	eval-rmse:0.00870
# [53]	train-rmse:0.00544	eval-rmse:0.00870
# [54]	train-rmse:0.00543	eval-rmse:0.00870
# [55]	train-rmse:0.00543	eval-rmse:0.00870
# [56]	train-rmse:0.00542	eval-rmse:0.00870
# [57]	train-rmse:0.00539	eval-rmse:0.00868
# [58]	train-rmse:0.00535	eval-rmse:0.00869
# [59]	train-rmse:0.00533	eval-rmse:0.00868
# [60]	train-rmse:0.00531	eval-rmse:0.00869
# [61]	train-rmse:0.00528	eval-rmse:0.00869
# [62]	train-rmse:0.00525	eval-rmse:0.00868
# [63]	train-rmse:0.00522	eval-rmse:0.00867
# [64]	train-rmse:0.00521	eval-rmse:0.00867
# [65]	train-rmse:0.00518	eval-rmse:0.00866
# [66]	train-rmse:0.00515	eval-rmse:0.00865
# [67]	train-rmse:0.00513	eval-rmse:0.00865
# [68]	train-rmse:0.00512	eval-rmse:0.00866
# [69]	train-rmse:0.00512	eval-rmse:0.00866
# [70]	train-rmse:0.00510	eval-rmse:0.00865
# [71]	train-rmse:0.00510	eval-rmse:0.00865
# [72]	train-rmse:0.00509	eval-rmse:0.00865
# [73]	train-rmse:0.00508	eval-rmse:0.00865
# [74]	train-rmse:0.00507	eval-rmse:0.00865
# [75]	train-rmse:0.00506	eval-rmse:0.00866
# [76]	train-rmse:0.00505	eval-rmse:0.00866
# [77]	train-rmse:0.00504	eval-rmse:0.00866
# [78]	train-rmse:0.00502	eval-rmse:0.00866
# [79]	train-rmse:0.00501	eval-rmse:0.00866
# [80]	train-rmse:0.00499	eval-rmse:0.00866
# [81]	train-rmse:0.00497	eval-rmse:0.00865
# [82]	train-rmse:0.00494	eval-rmse:0.00866
# [83]	train-rmse:0.00491	eval-rmse:0.00865
# [84]	train-rmse:0.00490	eval-rmse:0.00865
# [85]	train-rmse:0.00490	eval-rmse:0.00865
# [86]	train-rmse:0.00486	eval-rmse:0.00865
# [87]	train-rmse:0.00485	eval-rmse:0.00865
# [88]	train-rmse:0.00483	eval-rmse:0.00865
# [89]	train-rmse:0.00482	eval-rmse:0.00865
# [90]	train-rmse:0.00482	eval-rmse:0.00865
# [91]	train-rmse:0.00480	eval-rmse:0.00865
# [92]	train-rmse:0.00478	eval-rmse:0.00864
# [93]	train-rmse:0.00475	eval-rmse:0.00864
# [94]	train-rmse:0.00474	eval-rmse:0.00863
# [95]	train-rmse:0.00473	eval-rmse:0.00863
# [96]	train-rmse:0.00472	eval-rmse:0.00863
# [97]	train-rmse:0.00471	eval-rmse:0.00863
# [98]	train-rmse:0.00470	eval-rmse:0.00864
# [99]	train-rmse:0.00470	eval-rmse:0.00864
# [100]	train-rmse:0.00469	eval-rmse:0.00864
# [101]	train-rmse:0.00467	eval-rmse:0.00864
# [102]	train-rmse:0.00466	eval-rmse:0.00864
# [103]	train-rmse:0.00465	eval-rmse:0.00864
# [104]	train-rmse:0.00464	eval-rmse:0.00864
# [105]	train-rmse:0.00462	eval-rmse:0.00864
# [106]	train-rmse:0.00461	eval-rmse:0.00864
# [107]	train-rmse:0.00460	eval-rmse:0.00863
# [108]	train-rmse:0.00459	eval-rmse:0.00864
# [109]	train-rmse:0.00457	eval-rmse:0.00864
# [110]	train-rmse:0.00456	eval-rmse:0.00864
# [111]	train-rmse:0.00455	eval-rmse:0.00864
# [112]	train-rmse:0.00454	eval-rmse:0.00864
# [113]	train-rmse:0.00453	eval-rmse:0.00864
# [114]	train-rmse:0.00452	eval-rmse:0.00864
# [115]	train-rmse:0.00450	eval-rmse:0.00863
# [116]	train-rmse:0.00449	eval-rmse:0.00864
# [117]	train-rmse:0.00447	eval-rmse:0.00864
# [118]	train-rmse:0.00447	eval-rmse:0.00864
# [119]	train-rmse:0.00446	eval-rmse:0.00864
# [120]	train-rmse:0.00445	eval-rmse:0.00864
# [121]	train-rmse:0.00444	eval-rmse:0.00864
# [122]	train-rmse:0.00443	eval-rmse:0.00864
# [123]	train-rmse:0.00443	eval-rmse:0.00863
# [124]	train-rmse:0.00441	eval-rmse:0.00863
# [125]	train-rmse:0.00439	eval-rmse:0.00863
# [126]	train-rmse:0.00438	eval-rmse:0.00863
# [127]	train-rmse:0.00437	eval-rmse:0.00863
# [128]	train-rmse:0.00435	eval-rmse:0.00863
# [129]	train-rmse:0.00435	eval-rmse:0.00863
# [130]	train-rmse:0.00434	eval-rmse:0.00863
# [131]	train-rmse:0.00434	eval-rmse:0.00863
# [132]	train-rmse:0.00432	eval-rmse:0.00863
# [133]	train-rmse:0.00432	eval-rmse:0.00863
# [134]	train-rmse:0.00430	eval-rmse:0.00864
# [135]	train-rmse:0.00430	eval-rmse:0.00864
# [136]	train-rmse:0.00429	eval-rmse:0.00863
# [137]	train-rmse:0.00428	eval-rmse:0.00863
# [138]	train-rmse:0.00427	eval-rmse:0.00863
# [139]	train-rmse:0.00427	eval-rmse:0.00863
# [140]	train-rmse:0.00426	eval-rmse:0.00863
# [141]	train-rmse:0.00425	eval-rmse:0.00863
# [142]	train-rmse:0.00421	eval-rmse:0.00862
# [143]	train-rmse:0.00421	eval-rmse:0.00862
# [144]	train-rmse:0.00419	eval-rmse:0.00862
# [145]	train-rmse:0.00417	eval-rmse:0.00862
# [146]	train-rmse:0.00416	eval-rmse:0.00861
# [147]	train-rmse:0.00414	eval-rmse:0.00861
# [148]	train-rmse:0.00413	eval-rmse:0.00861
# [149]	train-rmse:0.00413	eval-rmse:0.00861
# [150]	train-rmse:0.00411	eval-rmse:0.00861
# [151]	train-rmse:0.00411	eval-rmse:0.00861
# [152]	train-rmse:0.00410	eval-rmse:0.00860
# [153]	train-rmse:0.00408	eval-rmse:0.00860
# [154]	train-rmse:0.00407	eval-rmse:0.00860
# [155]	train-rmse:0.00406	eval-rmse:0.00860
# [156]	train-rmse:0.00405	eval-rmse:0.00860
# [157]	train-rmse:0.00404	eval-rmse:0.00860
# [158]	train-rmse:0.00404	eval-rmse:0.00860
# [159]	train-rmse:0.00402	eval-rmse:0.00860
# [160]	train-rmse:0.00401	eval-rmse:0.00859
# [161]	train-rmse:0.00400	eval-rmse:0.00859
# [162]	train-rmse:0.00399	eval-rmse:0.00859
# [163]	train-rmse:0.00398	eval-rmse:0.00859
# [164]	train-rmse:0.00397	eval-rmse:0.00859
# [165]	train-rmse:0.00397	eval-rmse:0.00859
# [166]	train-rmse:0.00395	eval-rmse:0.00859
# [167]	train-rmse:0.00395	eval-rmse:0.00859
# [168]	train-rmse:0.00394	eval-rmse:0.00859
# [169]	train-rmse:0.00393	eval-rmse:0.00859
# [170]	train-rmse:0.00392	eval-rmse:0.00860
# [171]	train-rmse:0.00392	eval-rmse:0.00860
# [172]	train-rmse:0.00392	eval-rmse:0.00860
# [173]	train-rmse:0.00391	eval-rmse:0.00860
# [174]	train-rmse:0.00390	eval-rmse:0.00860
# [175]	train-rmse:0.00390	eval-rmse:0.00860
# [176]	train-rmse:0.00389	eval-rmse:0.00860
# [177]	train-rmse:0.00389	eval-rmse:0.00860
# [178]	train-rmse:0.00388	eval-rmse:0.00860
# [179]	train-rmse:0.00387	eval-rmse:0.00860
# [180]	train-rmse:0.00387	eval-rmse:0.00860
# [181]	train-rmse:0.00386	eval-rmse:0.00860
# [182]	train-rmse:0.00386	eval-rmse:0.00860
# [183]	train-rmse:0.00385	eval-rmse:0.00860
# [184]	train-rmse:0.00385	eval-rmse:0.00860
# [185]	train-rmse:0.00385	eval-rmse:0.00860
# [186]	train-rmse:0.00384	eval-rmse:0.00860
# [187]	train-rmse:0.00384	eval-rmse:0.00860
# [188]	train-rmse:0.00384	eval-rmse:0.00860
# [189]	train-rmse:0.00382	eval-rmse:0.00860
# [190]	train-rmse:0.00381	eval-rmse:0.00860
# [191]	train-rmse:0.00381	eval-rmse:0.00860
# [192]	train-rmse:0.00380	eval-rmse:0.00860
# [193]	train-rmse:0.00380	eval-rmse:0.00860
# [194]	train-rmse:0.00379	eval-rmse:0.00860
# [195]	train-rmse:0.00379	eval-rmse:0.00860
# [196]	train-rmse:0.00378	eval-rmse:0.00860
# [197]	train-rmse:0.00377	eval-rmse:0.00860
# [198]	train-rmse:0.00376	eval-rmse:0.00860
# [199]	train-rmse:0.00375	eval-rmse:0.00860
# [200]	train-rmse:0.00374	eval-rmse:0.00860
# [201]	train-rmse:0.00373	eval-rmse:0.00860
# [202]	train-rmse:0.00372	eval-rmse:0.00860
# [203]	train-rmse:0.00372	eval-rmse:0.00860
# [204]	train-rmse:0.00371	eval-rmse:0.00860
# [205]	train-rmse:0.00371	eval-rmse:0.00860
# [206]	train-rmse:0.00370	eval-rmse:0.00860
# [207]	train-rmse:0.00369	eval-rmse:0.00860
# [208]	train-rmse:0.00369	eval-rmse:0.00860
# [209]	train-rmse:0.00368	eval-rmse:0.00860
# [210]	train-rmse:0.00368	eval-rmse:0.00860
# [211]	train-rmse:0.00367	eval-rmse:0.00860
# [212]	train-rmse:0.00367	eval-rmse:0.00860
# seed2022, fold3, score [0.9991618528880426]

# %%
score = get_score(targets, oof_df)
LOGGER.info(f"xgb score {score}")
# Out:
# xgb score [0.8691720216622354]

# %%
train["score"] = oof_df

train.to_csv(f"{OUTPUT_DIR}oof_xgb_df.csv",index=False)

# %%
gbdt = (pd.read_csv(f"{OUTPUT_DIR}oof_lgbm_df.csv") + pd.read_csv(f"{OUTPUT_DIR}oof_xgb_df.csv"))["score"]/2

# %%
score = get_score(targets, gbdt)
LOGGER.info(f"gbdt averaging {score}")
# Out:
# gbdt averaging 0.8679955827518955
